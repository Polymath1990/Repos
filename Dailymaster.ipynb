# %%
import pandas as pd

# %%
import numpy as np

# %%
toby= pd.read_csv('tobisuccessfulvendors.csv')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (132,161) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
febpay= pd.read_csv('febpaystack.csv')

# %%
bayora = pd.read_csv('testrealcod.csv',encoding='latin-1')

# %%
febpay
# Out:
#         Status         Id        Reference Channel  \
# 0      success  183492816    1559126258026    card
# 1      success  183494537     trx_wwlexe35    card
# 2      success  183496122     trx_f45oifx7    card
# 3      success  183547349     trx_1xvlov89    card
# 4      success  183548463     trx_pj2c117k    card
# ...        ...        ...              ...     ...
# 29524  success  996908958  jr162r8gb56j1ar    card
# 29525  success  996909058  xxw8gt1tcbxk3hm    card
# 29526  success  996910186  uzr7b8vjlrmwnv6    card
# 29527  success  996929538  01tgmfkosb10ltq    card
# 29528  success  996937172  xdd89f4683wdlt9    card
#
#                        Created At Currency  Amount    Fees  Amount Due  \
# 0      May 29th, 2019 10:37:39 AM      NGN    50.0    0.75       49.25
# 1      May 29th, 2019 10:43:24 AM      NGN    50.0    0.75       49.25
# 2      May 29th, 2019 10:48:17 AM      NGN    50.0    0.75       49.25
# ...

# %%
cod['authentic_phone_no'] = cod['authentic_phone_no'].str[1:]

# %%
cod
# Out:
#        vendor_id  customer_id authentic_phone_no  freshsales_contact_id
# 0              1          1.0       919999999999           5.004481e+09
# 1              2          2.0        18768768765           5.004481e+09
# 2              5          5.0       918080808080           5.004482e+09
# 3              7          7.0       918768768768                    NaN
# 4             11         12.0      2349870369870           5.004530e+09
# ...          ...          ...                ...                    ...
# 34341      34681      45152.0      2349056040246           5.007644e+09
# 34342      34682      45153.0      2348164019691           5.007644e+09
# 34343      34683      45156.0      2348065231715           5.007644e+09
# 34344      34684      45157.0      2347025087889           5.007644e+09
# 34345      34685      45165.0      2347089025790           5.007644e+09
#
# [34346 rows x 4 columns]

# %%
tobi = pd.DataFrame(toby)

# %%
tobi
# Out:
#       vendor_id  is_created_by_admin description  user_id  \
# 0         22938                    1  Regulatory        1
# 1         22938                    1  Regulatory        1
# 2         22938                    1  Regulatory        1
# 3         22938                    1  Regulatory        1
# 4         22938                    1  Regulatory        1
# ...         ...                  ...         ...      ...
# 4914      36535                    1         NaN        1
# 4915      36535                    1         NaN        1
# 4916      36535                    1         NaN        1
# 4917      36535                    1         NaN        1
# 4918      36535                    1         NaN        1
#
#                           access_token                          password  \
# 0     d8f6f28fc1370d53c51f5a6ded6507f4  e10adc3949ba59abbe56e057f20f883e
# 1     d8f6f28fc1370d53c51f5a6ded6507f4  e10adc3949ba59abbe56e057f20f883e
# ...

# %%
tobijan = tobi[(tobi['job_date'] > '2020-12-31') & (tobi['job_date'] < '2021-02-01')]

# %%
tobifeb = tobi[(tobi['job_date'] > '2021-01-31') & (tobi['job_date'] < '2021-03-01')]

# %%
tobijanfill = tobijan[["vendor_id", "total_amount", "unique_order_id","job_date"]]

# %%
tobifebfill = tobifeb[["vendor_id", "total_amount", "unique_order_id","job_date"]]

# %%
bayo
# Out:
#       vendor_id  total_amount unique_order_id    job_date
# 1         22938        1351.2     105658BW738  2021-01-15
# 4         22938        2971.3     108192BX945  2021-01-05
# 8         12307        8302.1     109235BY396  2021-01-04
# 10        12307        2405.3     109287BY421  2021-01-04
# 14         2276        1267.1     109329BY441  2021-01-01
# ...         ...           ...             ...         ...
# 2645      33404        2700.0     119498CD046  2021-01-31
# 2647       5712         823.1     119510CD052  2021-01-31
# 2649      33404        1600.0     119536CD065  2021-01-31
# 2651       5712         822.2     119538CD066  2021-01-31
# 2653       5712         781.5     119556CD075  2021-01-31
#
# [777 rows x 4 columns]

# %%
pley = bayor.groupby('vendor_id')['total_amount'].sum()

# %%
bee = bayo.groupby(['vendor_id', 'total_amount']).sum()

# %%
pley
# Out:
# vendor_id
# 587        9900.0
# 621        9074.1
# 2276     222532.2
# 2303      31758.1
# 2474      11623.6
#            ...
# 35549      2200.0
# 35557      1100.0
# 35563      6900.0
# 36080      1700.0
# 36535      9165.6
# Name: total_amount, Length: 61, dtype: float64

# %%
player = pd.DataFrame(play)

# %%
pley.to_csv('febcorpamount.csv', index = False)

# %%
bee.to_csv('febcorporder.csv', index = False)

# %%
playoo =player.reset_index()

# %%
playoo
# Out:
#     vendor_id  total_amount
# 0         587       22200.0
# 1         621        3805.3
# 2        1504        2100.0
# 3        2067        2000.0
# 4        2276      384855.7
# 5        2303       25178.9
# 6        4337       18458.7
# 7        4396       46628.2
# 8        5190       18176.5
# 9        5712       50878.4
# 10       9262        3433.6
# 11       9264        2193.4
# 12       9268        1519.4
# 13       9276        7336.1
# 14       9286        2283.1
# 15       9482        1100.0
# 16       9500       11429.5
# 17      11553           0.0
# 18      12046           0.0
# 19      12307      459309.5
# 20      12740        5400.0
# 21      14719        6400.0
# 22      14905       12100.0
# 23      15676        8400.0
# 24      15797        2724.7
# 25      22345      234612.1
# 26      22936        2519.7
# 27      22938      185362.6
# 28      23681       13404.2
# 29      23743        5176.5
# 30      23862       44118.3
# 31      25607       11700.0
# ...

# %%
vey = tobijanfill.groupby(['vendor_id']).sum()

# %%
vee = tobijanfill.groupby(['unique_order_id']).count()

# %%
bayor = tobifebfill.sort_values('unique_order_id').drop_duplicates(subset=['vendor_id', 'total_amount'], keep='last')

# %%
bayor
# Out:
#       vendor_id  total_amount unique_order_id    job_date
# 2596       2303        1536.9     119063CC838  2021-02-01
# 2655      33207        1700.0     119654CD121  2021-02-01
# 2657       2276        1752.6     119656CD122  2021-02-01
# 2661      22345        3296.3     119666CD127  2021-02-01
# 2665      22938        1991.1     119670CD128  2021-02-01
# ...         ...           ...             ...         ...
# 4908      36535        1000.0     130366CI122  2021-02-28
# 4912      36535        1197.2     130402CI140  2021-02-28
# 4914      36535        1200.0     130404CI141  2021-02-28
# 4916      36535         900.0     130408CI143  2021-02-28
# 4918      36535        1300.0     130416CI147  2021-02-28
#
# [742 rows x 4 columns]

# %%
baz = bayor.groupby(['vendor_id']).count()

# %%
bee = baz.reset_index()

# %%
bee
# Out:
#     vendor_id  total_amount  unique_order_id  job_date
# 0         587             7                7         7
# 1         621             4                4         4
# 2        2276           135              135       135
# 3        2303            15               15        15
# 4        2474             4                4         4
# ..        ...           ...              ...       ...
# 56      35549             1                1         1
# 57      35557             1                1         1
# 58      35563             4                4         4
# 59      36080             1                1         1
# 60      36535             9                9         9
#
# [61 rows x 4 columns]

# %%
tobijanfill
# Out:
#       vendor_id  total_amount unique_order_id    job_date
# 0         22938        1351.2     105658BW738  2021-01-15
# 1         22938        1351.2     105658BW738  2021-01-15
# 2         22938        2971.3     108192BX945  2021-01-05
# 3         22938        2971.3     108192BX945  2021-01-05
# 4         22938        2971.3     108192BX945  2021-01-05
# ...         ...           ...             ...         ...
# 2649      33404        1600.0     119536CD065  2021-01-31
# 2650       5712         822.2     119538CD066  2021-01-31
# 2651       5712         822.2     119538CD066  2021-01-31
# 2652       5712         781.5     119556CD075  2021-01-31
# 2653       5712         781.5     119556CD075  2021-01-31
#
# [2652 rows x 4 columns]

# %%
tobifebfill
# Out:
#       vendor_id  total_amount unique_order_id    job_date
# 2595       2303        1536.9     119063CC838  2021-02-01
# 2596       2303        1536.9     119063CC838  2021-02-01
# 2654      33207        1700.0     119654CD121  2021-02-01
# 2655      33207        1700.0     119654CD121  2021-02-01
# 2656       2276        1752.6     119656CD122  2021-02-01
# ...         ...           ...             ...         ...
# 4914      36535        1200.0     130404CI141  2021-02-28
# 4915      36535         900.0     130408CI143  2021-02-28
# 4916      36535         900.0     130408CI143  2021-02-28
# 4917      36535        1300.0     130416CI147  2021-02-28
# 4918      36535        1300.0     130416CI147  2021-02-28
#
# [2267 rows x 4 columns]

# %%
topbyte = pd.DataFrame(byte)

# %%
payfeb
# Out:
#         Status         Id        Reference Channel  \
# 0      success  183492816    1559126258026    card
# 1      success  183494537     trx_wwlexe35    card
# 2      success  183496122     trx_f45oifx7    card
# 3      success  183547349     trx_1xvlov89    card
# 4      success  183548463     trx_pj2c117k    card
# ...        ...        ...              ...     ...
# 29524  success  996908958  jr162r8gb56j1ar    card
# 29525  success  996909058  xxw8gt1tcbxk3hm    card
# 29526  success  996910186  uzr7b8vjlrmwnv6    card
# 29527  success  996929538  01tgmfkosb10ltq    card
# 29528  success  996937172  xdd89f4683wdlt9    card
#
#                        Created At Currency  Amount    Fees  Amount Due  \
# 0      May 29th, 2019 10:37:39 AM      NGN    50.0    0.75       49.25
# 1      May 29th, 2019 10:43:24 AM      NGN    50.0    0.75       49.25
# 2      May 29th, 2019 10:48:17 AM      NGN    50.0    0.75       49.25
# ...

# %%
cod
# Out:
#        vendor_id  customer_id authentic_phone_no  freshsales_contact_id
# 0              1          1.0      +919999999999           5.004481e+09
# 1              2          2.0       +18768768765           5.004481e+09
# 2              5          5.0      +918080808080           5.004482e+09
# 3              7          7.0      +918768768768                    NaN
# 4             11         12.0     +2349870369870           5.004530e+09
# ...          ...          ...                ...                    ...
# 34341      34681      45152.0     +2349056040246           5.007644e+09
# 34342      34682      45153.0     +2348164019691           5.007644e+09
# 34343      34683      45156.0     +2348065231715           5.007644e+09
# 34344      34684      45157.0     +2347025087889           5.007644e+09
# 34345      34685      45165.0     +2347089025790           5.007644e+09
#
# [34346 rows x 4 columns]

# %%
mast
# Out:
#         Status         Id        Reference Channel  \
# 0      success  183492816    1559126258026    card
# 1      success  183494537     trx_wwlexe35    card
# 2      success  183496122     trx_f45oifx7    card
# 3      success  183547349     trx_1xvlov89    card
# 4      success  183548463     trx_pj2c117k    card
# ...        ...        ...              ...     ...
# 28516  success  979338558  7udplxb36jgmuhd    card
# 28517  success  979340519     trx_3m0kjt20    card
# 28518  success  979341266  3fnrachqzgcgxpq    card
# 28519  success  979343429  pxjnxj7s68oyt65    card
# 28520  success  979345650  ii82wg2qgs0gddr    card
#
#                        Created At Currency  Amount   Fees  Amount Due  \
# 0      May 29th, 2019 10:37:39 AM      NGN    50.0   0.75       49.25
# 1      May 29th, 2019 10:43:24 AM      NGN    50.0   0.75       49.25
# 2      May 29th, 2019 10:48:17 AM      NGN    50.0   0.75       49.25
# ...

# %%
opeloyal = pd.DataFrame(opethirty)

# %%
yank
# Out:
#         Status         Id        Reference Channel  \
# 0      success  183492816    1559126258026    card
# 1      success  183494537     trx_wwlexe35    card
# 2      success  183496122     trx_f45oifx7    card
# 3      success  183547349     trx_1xvlov89    card
# 4      success  183548463     trx_pj2c117k    card
# ...        ...        ...              ...     ...
# 28357  success  976751627  yyeokf7nt6l53n9    card
# 28358  success  976753304  07bc5j33nu4b7f0    card
# 28359  success  976758596  gf7tpxdqpotvr33    card
# 28360  success  976761917  5v8slswssysjj0v    card
# 28361  success  976763645  tf58ippd4qbxyne    card
#
#                        Created At Currency  Amount   Fees  Amount Due  \
# 0      May 29th, 2019 10:37:39 AM      NGN    50.0   0.75       49.25
# 1      May 29th, 2019 10:43:24 AM      NGN    50.0   0.75       49.25
# 2      May 29th, 2019 10:48:17 AM      NGN    50.0   0.75       49.25
# ...

# %%
openewyear = pd.read_csv('mastercardnewyear.csv')

# %%
openew = pd.DataFrame(openewyear)

# %%
damdam= pd.read_csv('dammyreport.csv')

# %%
todayloyalty= pd.read_csv('todaymastercard.csv')

# %%
loyaltytoday = pd.DataFrame(todayloyalty)

# %%
loyaltytoday
# Out:
#         Status         Id        Reference Channel  \
# 0      success  183492816    1559126258026    card
# 1      success  183494537     trx_wwlexe35    card
# 2      success  183496122     trx_f45oifx7    card
# 3      success  183547349     trx_1xvlov89    card
# 4      success  183548463     trx_pj2c117k    card
# ...        ...        ...              ...     ...
# 26741  success  940911126  w08k9okxzrzky7z    card
# 26742  success  940912193  zf8q8wxickvz9ol    card
# 26743  success  940914508  wgkwlwr3psu1zou    card
# 26744  success  940927166  9je6xe2lh6clxxa    card
# 26745  success  940932647  q1sj4b2gcugzyss    card
#
#                        Created At Currency  Amount   Fees  Amount Due  \
# 0      May 29th, 2019 10:37:39 AM      NGN    50.0   0.75       49.25
# 1      May 29th, 2019 10:43:24 AM      NGN    50.0   0.75       49.25
# 2      May 29th, 2019 10:48:17 AM      NGN    50.0   0.75       49.25
# ...

# %%
doublemaster= pd.read_csv('doublemastercard.csv')

# %%
damcashtwo= pd.read_csv('cashtwentytwo.csv')

# %%
mayowapod= pd.read_csv('mayowapod.csv')

# %%
mayowacash= pd.read_csv('mayowacash.csv')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (2,70,95,99) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
mayowapaystack= pd.read_csv('mayowapaystack.csv')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (2,3,70,99,104,106) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
mayowapaga= pd.read_csv('mayowapaga.csv')

# %%
mayowamonthly= pd.read_csv('mayowamonthly.csv')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (3,70,95,99,104,106) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
ope= pd.read_csv('mastertwentytwo.csv')

# %%
opey = pd.DataFrame(ope)

# %%
failed= pd.read_csv('failedreport.csv')

# %%
cancel= pd.read_csv('cancelledreport.csv')

# %%
damtoday = pd.DataFrame(damdam)

# %%
canceltoday = pd.DataFrame(cancel)

# %%
failedtoday = pd.DataFrame(failed)

# %%
dmaster = pd.DataFrame(doublemaster)

# %%
mayorpod = pd.DataFrame(mayowapod)

# %%
mayorcash = pd.DataFrame(mayowacash)

# %%
mayorpaystack = pd.DataFrame(mayowapaystack)

# %%
mayorpaga = pd.DataFrame(mayowapaga)

# %%
mayormonthly = pd.DataFrame(mayowamonthly)

# %%
damtoh = pd.DataFrame(damtwo)

# %%
damcash = pd.DataFrame(damcashtwo)

# %%
timemaster
# Out:
#         Status         Id        Reference Channel  \
# 0      success  183492816    1559126258026    card
# 1      success  183494537     trx_wwlexe35    card
# 2      success  183496122     trx_f45oifx7    card
# 3      success  183547349     trx_1xvlov89    card
# 4      success  183548463     trx_pj2c117k    card
# ...        ...        ...              ...     ...
# 27637  success  962078054  rq9jd7n997g4jbw    card
# 27638  success  962089746  s2xirabwoh6t9ge    card
# 27639  success  962103239  1cvbc9qqovql9r8    card
# 27640  success  962105421  d76q6lr9gf93lbs    card
# 27641  success  962106317  5gyssgdbkmqxmzv    card
#
#                        Created At Currency  Amount    Fees  Amount Due  \
# 0      May 29th, 2019 10:37:39 AM      NGN    50.0    0.75       49.25
# 1      May 29th, 2019 10:43:24 AM      NGN    50.0    0.75       49.25
# 2      May 29th, 2019 10:48:17 AM      NGN    50.0    0.75       49.25
# ...

# %%
openew
# Out:
#         Status         Id        Reference Channel  \
# 0      success  183492816    1559126258026    card
# 1      success  183494537     trx_wwlexe35    card
# 2      success  183496122     trx_f45oifx7    card
# 3      success  183547349     trx_1xvlov89    card
# 4      success  183548463     trx_pj2c117k    card
# ...        ...        ...              ...     ...
# 27023  success  948213803  vqc41jyjxox5whk    card
# 27024  success  948230134  gv1eqznp6ucewal    card
# 27025  success  948231552  t7hyct6d4u1d2po    card
# 27026  success  948234667  343n10mclc2hraz    card
# 27027  success  948237556     trx_tbiv8iht    card
#
#                        Created At Currency  Amount    Fees  Amount Due  \
# 0      May 29th, 2019 10:37:39 AM      NGN    50.0    0.75       49.25
# 1      May 29th, 2019 10:43:24 AM      NGN    50.0    0.75       49.25
# 2      May 29th, 2019 10:48:17 AM      NGN    50.0    0.75       49.25
# ...

# %%
timemaster['job_date'] = pd.to_datetime(timemaster['Created At']).dt.to_period('M')

# %%
malog['day_year'] = pd.to_datetime(malog['Created At']).dt.to_period('D')

# %%
femi['job_date'] = pd.to_datetime(femi['Created At']).dt.to_period('M')

# %%
femi['day_year'] = pd.to_datetime(femi['Created At']).dt.to_period('D')

# %%
opexmaz['job_date'] = pd.to_datetime(opexmaz['Created At']).dt.to_period('M')

# %%
opexmaz['day_year'] = pd.to_datetime(opexmaz['Created At']).dt.to_period('D')

# %%
payfeb
# Out:
#         Status         Id        Reference Channel  \
# 0      success  183492816    1559126258026    card
# 1      success  183494537     trx_wwlexe35    card
# 2      success  183496122     trx_f45oifx7    card
# 3      success  183547349     trx_1xvlov89    card
# 4      success  183548463     trx_pj2c117k    card
# ...        ...        ...              ...     ...
# 29524  success  996908958  jr162r8gb56j1ar    card
# 29525  success  996909058  xxw8gt1tcbxk3hm    card
# 29526  success  996910186  uzr7b8vjlrmwnv6    card
# 29527  success  996929538  01tgmfkosb10ltq    card
# 29528  success  996937172  xdd89f4683wdlt9    card
#
#                        Created At Currency  Amount    Fees  Amount Due  \
# 0      May 29th, 2019 10:37:39 AM      NGN    50.0    0.75       49.25
# 1      May 29th, 2019 10:43:24 AM      NGN    50.0    0.75       49.25
# 2      May 29th, 2019 10:48:17 AM      NGN    50.0    0.75       49.25
# ...

# %%
mlog = malog[malog['Card Type'] == "mastercard DEBIT"]

# %%
opeloyal['job_date'] = pd.to_datetime(opeloyal['Created At']).dt.to_period('M')

# %%
opeloyal['day_year'] = pd.to_datetime(opeloyal['Created At']).dt.to_period('D')

# %%
loyaltytoday['job_date'] = pd.to_datetime(loyaltytoday['Created At']).dt.to_period('M')

# %%
loyaltytoday['day_year'] = pd.to_datetime(loyaltytoday['Created At']).dt.to_period('D')

# %%
dmaster['job_date'] = pd.to_datetime(dmaster['Created At']).dt.to_period('M')

# %%
dmaster['day_year'] = pd.to_datetime(dmaster['Created At']).dt.to_period('D')

# %%
maraba = mast[mast['day_year'] == "2021-01-28"]

# %%
opexmaxfilter = opexmaz[opexmaz['day_year'] == "2020-12-30"]

# %%
opefilter = opeloyal[opeloyal['day_year'] == "2020-12-29"]

# %%
opelatest = opey[opey['day_year'] == "2020-12-21"]

# %%
feblog = mlog[(mlog['day_year'] > '2021-02-01') & (mlog['day_year'] < '2021-02-16')]

# %%
yankee = yank[(yank['day_year'] > '2021-01-14') & (yank['day_year'] < '2021-01-27')]

# %%
feblog
# Out:
#         Status          Id        Reference Channel  \
# 28785  success   984395090  4x18c7uhozjnlfm    card
# 28788  success   984496772  v8am8poguvg3f74    card
# 28789  success   984526558  v68no3q1fl5s2xg    card
# 28790  success   984548025  a2i6zwlhu27ksqv    card
# 28793  success   984603104  fmtr2gl50ks2uuv    card
# ...        ...         ...              ...     ...
# 29879  success  1002029697    1613400684401    card
# 29882  success  1002041114  q5ti8l43bnh7uyh    card
# 29883  success  1002088157  kycxeaey44kg0mo    card
# 29884  success  1002132600  2a47724gpf33vqh    card
# 29887  success  1002141665  xdpy67tkhr263qc    card
#
#                        Created At Currency  Amount    Fees  Amount Due  \
# 28785   Feb 2nd, 2021 02:18:33 AM      NGN   100.0    1.50       98.50
# 28788   Feb 2nd, 2021 06:08:33 AM      NGN  3600.0  154.00     3446.00
# 28789   Feb 2nd, 2021 06:46:09 AM      NGN  2200.0   33.00     2167.00
# ...

# %%
loyaltea = loyaltytoday[(loyaltytoday['day_year'] > '2020-12-29') & (loyaltytoday['day_year'] < '2020-12-29')]

# %%
openewmaster = openew[(openew['day_year'] > '2020-12-29') & (openew['day_year'] < '2021-01-04')]

# %%
yoko
# Out:
#         Status         Id        Reference Channel  \
# 28353  success  976610115  8r1ib8exbnt29e3    card
# 28354  success  976711559  du8h44nqbbjpvel    card
# 28355  success  976724841  4pls1ab7vrw51o2    card
# 28356  success  976726906  glzd595hwl9k5ae    card
# 28357  success  976751627  yyeokf7nt6l53n9    card
# ...        ...        ...              ...     ...
# 28430  success  977354798  3e7dyjw0v08y3cn    card
# 28431  success  977377419  3eqewg21tqqr412    card
# 28432  success  977394809  19jejeb5tjih86c    card
# 28433  success  977557145  p0d7n9e41qmhx6p    card
# 28434  success  977741561  z76ke8uyxtp317w    card
#
#                        Created At Currency  Amount   Fees  Amount Due  \
# 28353  Jan 27th, 2021 04:19:09 AM      NGN  2900.0  143.5      2756.5
# 28354  Jan 27th, 2021 07:18:48 AM      NGN  1400.0   21.0      1379.0
# 28355  Jan 27th, 2021 07:34:27 AM      NGN  2500.0  137.5      2362.5
# ...

# %%
refinedmaster = dmaster[(dmaster['day_year'] > '2020-12-21') & (dmaster['day_year'] < '2020-12-24')]

# %%
logtwo = feblog[feblog['day_year'] == '2021-02-02']

# %%
logthree = feblog[feblog['day_year'] == '2021-02-03']

# %%
logfour = feblog[feblog['day_year'] == '2021-02-04']

# %%
logfive = feblog[feblog['day_year'] == '2021-02-05']

# %%
logsix = feblog[feblog['day_year'] == '2021-02-06']

# %%
logseven = feblog[feblog['day_year'] == '2021-02-07']

# %%
logeight = feblog[feblog['day_year'] == '2021-02-08']

# %%
lognine = feblog[feblog['day_year'] == '2021-02-09']

# %%
logten = feblog[feblog['day_year'] == '2021-02-10']

# %%
logfour
# Out:
#         Status         Id        Reference Channel                 Created At  \
# 28963  success  987179102  gb3xzujz8d3domv    card  Feb 4th, 2021 01:43:54 AM
# 28964  success  987220263  ovhdih9my6wsw84    card  Feb 4th, 2021 04:15:55 AM
# 28965  success  987296886     trx_06s4tkwy    card  Feb 4th, 2021 06:31:18 AM
# 28966  success  987298117     trx_68jscnjy    card  Feb 4th, 2021 06:33:39 AM
# 28967  success  987301162  0dlkpt448sjpqs7    card  Feb 4th, 2021 06:38:58 AM
# ...        ...        ...              ...     ...                        ...
# 29044  success  987960629  1xeggav80l95njl    card  Feb 4th, 2021 05:07:18 PM
# 29045  success  987964789  rlq9lkwb0c5wcpz    card  Feb 4th, 2021 05:10:57 PM
# 29046  success  987978015  g1eb79i382wnh8c    card  Feb 4th, 2021 05:22:24 PM
# 29047  success  987993485  z8aixoqi8cd3obl    card  Feb 4th, 2021 05:36:42 PM
# 29050  success  988045198  o4g95bpf6uef7pz    card  Feb 4th, 2021 06:22:07 PM
#
# ...

# %%
perflea = payflee[payflee['Card Type'] == "mastercard DEBIT"]

# %%
perflea = payflee[payflee['Card Type'] == "mastercard DEBIT"]

# %%
perry = perfone[perfone['Card Type'] == "mastercard DEBIT"]

# %%
cardalltime = mastertime[mastertime['Card Type'] == "mastercard DEBIT"]

# %%
carri = yokey[yokey['Customer Email'] == "luckyekanem@gmail.com"]

# %%
perry
# Out:
#         Status         Id        Reference Channel                 Created At  \
# 28694  success  983245459  7hzu5mzglo81xul    card  Feb 1st, 2021 06:38:20 AM
# 28698  success  983281254  f9ee1zfyt9ivrjl    card  Feb 1st, 2021 07:32:14 AM
# 28699  success  983281364  8egkccyo0tfxzgw    card  Feb 1st, 2021 07:32:21 AM
# 28700  success  983281976  u78fdiip1il29ue    card  Feb 1st, 2021 07:33:00 AM
# 28702  success  983312655  dpnvbzafligdvzy    card  Feb 1st, 2021 08:11:12 AM
# ...        ...        ...              ...     ...                        ...
# 28778  success  983754400  zxj8gc6xk0r6343    card  Feb 1st, 2021 03:39:15 PM
# 28780  success  983762210  oxqk6cpi1o1n45f    card  Feb 1st, 2021 03:45:18 PM
# 28781  success  983769914  07ld4ioik2dw0fz    card  Feb 1st, 2021 03:51:03 PM
# 28782  success  983847088  lvvp4lhqo3nxnxg    card  Feb 1st, 2021 04:55:00 PM
# 28783  success  983998591  rmme7v400d3hqxc    card  Feb 1st, 2021 07:09:00 PM
#
# ...

# %%
bayotoday = loyaltea[loyaltea['Card Type'] == "mastercard DEBIT"]

# %%
opeyx
# Out:
#         Status         Id        Reference Channel  \
# 26792  success  942102508  jz29qxikhey7lfz    card
# 26793  success  942137218  shzlepqq893dlmx    card
# 26794  success  942141668  ugpsi50p5ngmsj7    card
# 26795  success  942143156  pdsvvvfao05v2dw    card
# 26796  success  942150422  5fvwi2kj2xwvm1s    card
# ...        ...        ...              ...     ...
# 26867  success  942864887     trx_4gxztilu    card
# 26868  success  942865866  lwyncf3xic82wwl    card
# 26869  success  942885753  3y728jcszaixhw8    card
# 26870  success  942902571  g8zanwymy3c2cj8    card
# 26871  success  943089715  i0lbwv3zyf7pftk    card
#
#                        Created At Currency  Amount    Fees  Amount Due  \
# 26792  Dec 30th, 2020 05:41:49 AM      NGN  1000.0   15.00      985.00
# 26793  Dec 30th, 2020 06:32:40 AM      NGN  2000.0   30.00     1970.00
# 26794  Dec 30th, 2020 06:38:44 AM      NGN  2900.0  143.50     2756.50
# ...

# %%
# Out:
#         Status         Id        Reference Channel  \
# 26462  success  934794626  bnk4uaj017ttrnk    card
# 26463  success  934852773  bt4oqbyr1w0dsxv    card
# 26464  success  934890835  zoao36znotf0z5o    card
# 26465  success  934899574     trx_t3nm2556    card
# 26466  success  934899834  qecv9ygte4k5mdm    card
# ...        ...        ...              ...     ...
# 26726  success  940186176  qhum4u9455kxc06    card
# 26727  success  940236928  9tektmc6lojz27m    card
# 26728  success  940265346  xyprxdenu1rjuvt    card
# 26729  success  940266228  oqpbpbrrna3mi8d    card
# 26730  success  940358383  km83c0xg5t00s97    card
#
#                        Created At Currency  Amount    Fees  Amount Due  \
# 26462  Dec 24th, 2020 01:01:31 AM      NGN  3700.0  155.50     3544.50
# 26463  Dec 24th, 2020 02:53:13 AM      NGN  2400.0   36.00     2364.00
# 26464  Dec 24th, 2020 04:27:43 AM      NGN  1300.0   19.50     1280.50
# ...

# %%
loyaltie
# Out:
#         Status         Id        Reference Channel  \
# 26161  success  932200920     trx_qgn22xqv    card
# 26162  success  932201390  bheczpe3gefzku8    card
# 26163  success  932207894  7xee9xkt7671oy3    card
# 26164  success  932216762     trx_zwreh83a    card
# 26165  success  932217102  8pd0wb5swnjvcn1    card
# ...        ...        ...              ...     ...
# 26460  success  934560828  2vhj03naopm7wn0    card
# 26461  success  934609375  v3twbz914u68rca    card
# 26462  success  934671521  4lnmqurvbmd4tpo    card
# 26463  success  934717061  au18dwl2feirw0i    card
# 26464  success  934718850  vvtxaqw50ejgvhr    card
#
#                        Created At Currency  Amount    Fees  Amount Due  \
# 26161  Dec 22nd, 2020 05:31:31 AM      NGN    50.0    0.75       49.25
# 26162  Dec 22nd, 2020 05:32:22 AM      NGN  1600.0   24.00     1576.00
# 26163  Dec 22nd, 2020 05:43:19 AM      NGN   700.0   10.50      689.50
# ...

# %%
listweekend
# Out:
#         Status         Id        Reference Channel  \
# 25740  success  927118093  kojwqjl01fax2d9    card
# 25741  success  927121301  wkbv5a5wjfzynrp    card
# 25742  success  927151433  rk6u7kheulsq7pn    card
# 25743  success  927151733    1608272511070    card
# 25744  success  927155192  n2wg1w3w4jv7wy1    card
# ...        ...        ...              ...     ...
# 26001  success  930251407     trx_bf1hhuc9    card
# 26002  success  930257537  fbs4lfzolceprvz    card
# 26005  success  930337649  dk53rczqblrob1f    card
# 26006  success  930404717  qrbp5nmeau3y027    card
# 26012  success  930746772  pi6cmohg7y95h3s    card
#
#                        Created At Currency  Amount    Fees  Amount Due  \
# 25740  Dec 18th, 2020 05:27:51 AM      NGN  2400.0   36.00     2364.00
# 25741  Dec 18th, 2020 05:34:14 AM      NGN  1700.0   25.50     1674.50
# 25742  Dec 18th, 2020 06:21:29 AM      NGN  2500.0  137.50     2362.50
# ...

# %%
bayotoday
# Out:
#         Status         Id        Reference Channel  \
# 26462  success  934794626  bnk4uaj017ttrnk    card
# 26463  success  934852773  bt4oqbyr1w0dsxv    card
# 26464  success  934890835  zoao36znotf0z5o    card
# 26465  success  934899574     trx_t3nm2556    card
# 26466  success  934899834  qecv9ygte4k5mdm    card
# ...        ...        ...              ...     ...
# 26726  success  940186176  qhum4u9455kxc06    card
# 26727  success  940236928  9tektmc6lojz27m    card
# 26728  success  940265346  xyprxdenu1rjuvt    card
# 26729  success  940266228  oqpbpbrrna3mi8d    card
# 26730  success  940358383  km83c0xg5t00s97    card
#
#                        Created At Currency  Amount    Fees  Amount Due  \
# 26462  Dec 24th, 2020 01:01:31 AM      NGN  3700.0  155.50     3544.50
# 26463  Dec 24th, 2020 02:53:13 AM      NGN  2400.0   36.00     2364.00
# 26464  Dec 24th, 2020 04:27:43 AM      NGN  1300.0   19.50     1280.50
# ...

# %%
mailweek = cardalltime["Customer Email"].unique()

# %%
tastree = bayotoday.groupby('Customer Email')

# %%
taste = bayotoday.groupby('Customer Email').apply(print)
# Out:
#         Status         Id        Reference Channel  \
# 26685  success  939642798  r0as6kayo0q99br    card
#
#                        Created At Currency  Amount  Fees  Amount Due  \
# 26685  Dec 28th, 2020 08:34:45 AM      NGN  1700.0  25.5      1674.5
#
#                    Customer Email         Card Type         Bank job_date  \
# 26685  adebara.sulaimon@gmail.com  mastercard DEBIT  Zenith Bank  2020-12
#
#          day_year
# 26685  2020-12-28
#         Status         Id        Reference Channel  \
# 26729  success  940266228  oqpbpbrrna3mi8d    card
#
#                        Created At Currency  Amount  Fees  Amount Due  \
# 26729  Dec 28th, 2020 05:51:02 PM      NGN  2100.0  31.5      2068.5
#
#                 Customer Email         Card Type                   Bank  \
# 26729  adebowalemide@yahoo.com  mastercard DEBIT  First Bank of Nigeria
#
#       job_date    day_year
# 26729  2020-12  2020-12-28
#         Status         Id        Reference Channel  \
# ...

# %%
taste = bayotoday.groupby('Customer Email')
for key, item in taste:
    print(taste.get_group(key), "\n\n")
# Out:
#         Status         Id        Reference Channel  \
# 26685  success  939642798  r0as6kayo0q99br    card
#
#                        Created At Currency  Amount  Fees  Amount Due  \
# 26685  Dec 28th, 2020 08:34:45 AM      NGN  1700.0  25.5      1674.5
#
#                    Customer Email         Card Type         Bank job_date  \
# 26685  adebara.sulaimon@gmail.com  mastercard DEBIT  Zenith Bank  2020-12
#
#          day_year
# 26685  2020-12-28
#
#
#         Status         Id        Reference Channel  \
# 26729  success  940266228  oqpbpbrrna3mi8d    card
#
#                        Created At Currency  Amount  Fees  Amount Due  \
# 26729  Dec 28th, 2020 05:51:02 PM      NGN  2100.0  31.5      2068.5
#
#                 Customer Email         Card Type                   Bank  \
# 26729  adebowalemide@yahoo.com  mastercard DEBIT  First Bank of Nigeria
#
#       job_date    day_year
# 26729  2020-12  2020-12-28
#
#
#         Status         Id        Reference Channel  \
# ...

# %%
teez = taste.apply(lambda x: x['Amount'].unique())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d55dd9cb6eba> in <module>
# ----> 1 teez = taste.apply(lambda x: x['Amount'.sum()].unique())
#
# NameError: name 'taste' is not defined

# %%
topey = teez.reset_index()

# %%
yankey
# Out:
#         Status         Id        Reference Channel  \
# 27589  success  961795463  cgwezwdu652gvb6    card
# 27590  success  961799104  gdd95fn4gwsrjo4    card
# 27591  success  961811628  bwtm4416fkj07u4    card
# 27592  success  961817056  gwexzw373aywejw    card
# 27593  success  961846582  as9xax9562xbmk1    card
# ...        ...        ...              ...     ...
# 28348  success  976056126  eaykhd71hdcw7ui    card
# 28349  success  976099141     trx_ebngxmxa    card
# 28350  success  976142138  lh48r1l6ldulnmq    card
# 28351  success  976207155  rjvpvcmzgbxis71    card
# 28352  success  976262027  us3pnc8cqrwyd1i    card
#
#                        Created At Currency  Amount    Fees  Amount Due  \
# 27589  Jan 15th, 2021 08:17:53 AM      NGN  3500.0  152.50     3347.50
# 27590  Jan 15th, 2021 08:21:49 AM      NGN  1900.0   28.50     1871.50
# 27591  Jan 15th, 2021 08:35:12 AM      NGN  2700.0  140.50     2559.50
# ...

# %%
mailweek = logeight["Customer Email"]

# %%
mailweekunique = mailweek.unique()

# %%
mailweekunique
# Out:
# array(['davidoduro@yahoo.com', 'favourdamilola1@gmail.com',
#        'ajibesinabiodun@gmail.com', 'ozone14800@yahoo.com',
#        'kelvinagum@gmail.com', 'thefoodboxng@gmail.com',
#        'jessicaduke80@gmail.com', 'kenerapu@gmail.com',
#        'adejumoabisola1@gmail.com', 'fatimah4u2mail@yahoo.com',
#        'obichukwu.nwachukwu@gmail.com', 'rotimiajala@gmail.com',
#        'info@bola3.com', 'youssef@mistachoco.com', 'feyisikef@yahoo.com',
#        'ujubuonuokwudili@gmail.com', 'service@my36chocolates.ng',
#        'generaljunee@gmail.com', 'lajuomagbitse@gmail.com',
#        'bayode@alwaysme.ng', 'bolu.deyanju@gmail.com',
#        'consistentolusesi@gmail.com', 'omosalewabadejo@gmail.com',
#        'jinkaz037@gmail.com', 'taofahmed3@gmail.com',
#        'deyheencar@yahoo.com', 'bakwaibags@gmail.com', 'redu54@gmail.com',
#        'ololade@kudabank.com', 'toniamaduka@hotmail.com',
#        'kenny@medsaf.com', 'yinka_ogboye@yahoo.com',
# ...

# %%
mailall = pd.DataFrame(mailweekunique)

# %%
mailall.to_csv('logeight.csv', index = False)

# %%
# Out:
#                                         0
# 0                     makanakey@gmail.com
# 1                 mary4christ69@gmail.com
# 2                  ibesmithblog@gmail.com
# 3                  aishat.alimi@gmail.com
# 4                  temitopesola@yahoo.com
# 5                 sushxelestine@gmail.com
# 6                        glodit@yahoo.com
# 7                  rotimi.lopez@gmail.com
# 8                   emmanuel@trybrass.com
# 9                   mimipetti_4@yahoo.com
# 10                    ebunkunmi@yahoo.com
# 11                     kenerapu@gmail.com
# 12                      yenchoi@gmail.com
# 13                benkaliodinah@yahoo.com
# 14                    temi.giwa@gmail.com
# 15  dazzlejewellery.accessories@gmail.com
# 16                   deyheencar@yahoo.com
# 17                  maibiskit27@gmail.com
# 18                  sadeonabowale@aol.com
# 19            oluwaseunpeters@hotmail.com
# 20                   mohinihair@gmail.com
# ...

# %%
carri.to_csv('carry.csv', index = False)

# %%
mailall
# Out:
#                              0
# 0          leumas920@gmail.com
# 1    calseindustries@gmail.com
# 2         daekundayo@gmail.com
# 3          temi.giwa@gmail.com
# 4   ajibola_muhammed@yahoo.com
# ..                         ...
# 60    primeangel2003@yahoo.com
# 61     salamifatima4@gmail.com
# 62            edivri@gmail.com
# 63     renbekcompany@gmail.com
# 64      ibesmithblog@gmail.com
#
# [65 rows x 1 columns]

# %%
quick = pd.read_csv('kwikmoi.csv')

# %%
bayokay = pd.read_csv('newmailall.csv')

# %%
# Out:
#   File "<ipython-input-24-efa2cfc19f05>", line 1
#     df1 = pd.DataFrame ([{'Customer_Email':['loulic67@gmail.com
#                                                                ^
# SyntaxError: EOL while scanning string literal

# %%
bayofirst = pd.read_csv('bayomastercard.csv')

# %%
bayosecond = pd.read_csv('newopera.csv')

# %%
bayorey = pd.read_csv('bayomastercard.csv')

# %%
bayomoi = pd.read_csv('moimoi.csv')

# %%
fizzle = pd.read_csv('newfinalelastyear.csv')

# %%
freshtwo = pd.read_csv('opefreshboy.csv')

# %%
blastlog = pd.read_csv('februarymastercard.csv')

# %%
newquick = pd.read_csv('newlogeight.csv')

# %%
refined = pd.read_csv('logeight.csv')

# %%
left = pd.DataFrame(newquick)

# %%
right = pd.DataFrame(logeight)

# %%
veedey = pd.merge(left,right,how ='inner', on ='vendor_id')

# %%
allmay = pd.merge(left,right,how ='inner', on ='Customer Email')

# %%
allmay
# Out:
#                    Customer Email   Status         Id        Reference  \
# 0       favourdamilola1@gmail.com  success  992687240  x6vw67tqjtjonjg
# 1          thefoodboxng@gmail.com  success  992759468  8r2i3g319sa1d8x
# 2         jessicaduke80@gmail.com  success  992771510  3nvmnpfmpqx35aa
# 3   obichukwu.nwachukwu@gmail.com  success  992844984  t1tokw2nvbknqay
# 4          youssef@mistachoco.com  success  992861824  0nrms7ca6bztmvq
# 5             feyisikef@yahoo.com  success  992870720  at2kaflr2brr8k2
# 6      ujubuonuokwudili@gmail.com  success  992877655     trx_u937d18l
# 7      ujubuonuokwudili@gmail.com  success  992878620  jc4x5eec5ibzojr
# 8       service@my36chocolates.ng  success  992882420  cdecl6o5dlfgi72
# 9          generaljunee@gmail.com  success  992893122  rlise7nkwqjv7r9
# 10        lajuomagbitse@gmail.com  success  992932941     trx_0xn3d274
# 11         bolu.deyanju@gmail.com  success  992945334  6kpzq25fzma3qub
# ...

# %%
allmay.to_csv('opelogeight.csv', index = False)

# %%
airbyte.to_csv('kwikbitesmail.csv', index = False)

# %%
car1 = moroh[moroh['Customer Email'] == "abigailomage40@gmail.com"]

# %%
car2 = moroh[moroh['Customer Email'] == "pillartunde43@gmail.com"]

# %%
car3 = moroh[moroh['Customer Email'] == "coleadedayo@yahoo.com"]

# %%
car4 = moroh[moroh['Customer Email'] == "boldutensils@gmail.com"]

# %%
car5 = moroh[moroh['Customer Email'] == "hustleboy93@yahoo.com"]

# %%
allcar = pd.concat([car1, car2, car3, car4, car5])

# %%
allcar.to_csv('todaymaster.csv', index = False)

# %%
airnine = airtime[airtime['day_year'] == "2021-01-29"]

# %%
airten = airtime[airtime['day_year'] == "2021-01-30"]

# %%
airone = airtime[airtime['day_year'] == "2021-01-31"]

# %%
jeighteen = topmaster[topmaster['day_year'] == "2021-01-18"]

# %%
jnineteen = topmaster[topmaster['day_year'] == "2021-01-19"]

# %%
jtwenty = topmaster[topmaster['day_year'] == "2021-01-20"]

# %%
jtwentyone = topmaster[topmaster['day_year'] == "2021-01-21"]

# %%
jtwentytwo = topmaster[topmaster['day_year'] == "2021-01-22"]

# %%
jtwentythree = topmaster[topmaster['day_year'] == "2021-01-23"]

# %%
jtwentyfour = topmaster[topmaster['day_year'] == "2021-01-24"]

# %%
jtwentyfive = topmaster[topmaster['day_year'] == "2021-01-25"]

# %%
jtwentysix = topmaster[topmaster['day_year'] == "2021-01-26"]

# %%
airnine.to_csv('twenine.csv', index = False)

# %%
airten.to_csv('thirty.csv', index = False)

# %%
airone.to_csv('thirtyone.csv', index = False)

# %%
jeighteen.to_csv('jeight.csv', index = False)

# %%
jnineteen.to_csv('jnine.csv', index = False)

# %%
jtwenty.to_csv('jtwenty.csv', index = False)

# %%
jtwentyone.to_csv('jtwentyone.csv', index = False)

# %%
jtwentytwo.to_csv('jtwentytwo.csv', index = False)

# %%
jtwentythree.to_csv('jtwentythree.csv', index = False)

# %%
jtwentyfour.to_csv('jtwentyfour.csv', index = False)

# %%
jtwentyfive.to_csv('jtwentyfive.csv', index = False)

# %%
jtwentysix.to_csv('jtwentysix.csv', index = False)

# %%
totalbayotoday.to_csv('finalebayotoday.csv', index = False)

# %%
kwiktwo = finaloyaltie[finaloyaltie['day_year'] == "2020-12-22"]

# %%
kwikthree = finaloyaltie[finaloyaltie['day_year'] == "2020-12-23"]

# %%
kwikthree.to_csv('kwiktwentythree.csv', index = False)

# %%
totalanny = pd.DataFrame(totalannie)

# %%
totalanny
# Out:
#              Customer Email   Status         Id        Reference Channel  \
# 0   tonia4smart@yahoo.co.uk  success  927118093  kojwqjl01fax2d9    card
# 1   tonia4smart@yahoo.co.uk  success  927121301  wkbv5a5wjfzynrp    card
# 2       laraoloja@gmail.com  success  927151433  rk6u7kheulsq7pn    card
# 3       akinzo234@gmail.com  success  927151733    1608272511070    card
# 4       akinzo234@gmail.com  success  927239176  tno6yx0fyq4uom6    card
# ..                      ...      ...        ...              ...     ...
# 58        signups@funsho.me  success  929964064           559141    card
# 59  segunbashorun@gmail.com  success  930022309  bv99k916lvzrmzm    card
# 60   tomihadybete@gmail.com  success  930251407     trx_bf1hhuc9    card
# 61      mikun2286@gmail.com  success  930257537  fbs4lfzolceprvz    card
# 62     n.agbanusi@gmail.com  success  930404717  qrbp5nmeau3y027    card
#
#                     Created At Currency  Amount    Fees  Amount Due  \
# ...

# %%
dayfriday = totalanny[totalanny['day_year'] == "2020-12-18"]

# %%
daysat = totalanny[totalanny['day_year'] == "2020-12-19"]

# %%
daysunday = totalanny[totalanny['day_year'] == "2020-12-20"]

# %%
dayfriday.to_csv('opefriday.csv', index = False)

# %%
daysat.to_csv('opesat.csv', index = False)

# %%
daysunday.to_csv('opesunday.csv', index = False)

# %%
anitafinalweekend.to_csv('annie.csv', index = False)

# %%
damtoday['job_date'] = pd.to_datetime(damtoday['job_time']).dt.to_period('M')

# %%
damtoday['day_year'] = pd.to_datetime(damtoday['job_time']).dt.to_period('D')

# %%
damtoday
# Out:
#        job_id  total_amount  payment_method             job_time  job_status  \
# 0           1          90.0               8  2019-06-14 18:44:00           2
# 1           3          90.0          262144  2019-06-14 18:47:00           2
# 2           5          70.0               8  2019-06-14 18:58:00           2
# 3           6          70.0               8  2019-06-14 19:22:00           2
# 4           7          70.0          262144  2019-06-17 11:15:00           2
# ...       ...           ...             ...                  ...         ...
# 90044  106531        1200.0              32  2020-12-24 10:48:00           2
# 90045  106533         100.0               8  2020-12-24 10:50:00           2
# 90046  106534         100.0               8  2020-12-24 11:01:00           2
# 90047  106542           0.0         2097152  2020-12-24 10:51:00           2
# 90048  106566        3000.0              32  2020-12-24 11:12:00           2
#
#       job_date    day_year
# ...

# %%
damfinal = damtoday[damtoday['day_year'] == "2020-12-23"]

# %%
refinedmaster = dmaster[(dmaster['day_year'] > '2020-12-21') & (dmaster['day_year'] < '2020-12-24')]

# %%
alldecember = damtoday[(damtoday['day_year'] > '2020-11-30') & (damtoday['day_year'] < '2020-12-24')]

# %%
testiey = alldecember.groupby('payment_method')

# %%
testiey

# %%
alldecember
# Out:
#        job_id  total_amount  payment_method             job_time  job_status  \
# 79593   93478       1478.20          524288  2020-12-17 08:36:00           2
# 79594   93479       1478.20          524288  2020-12-17 08:52:00           2
# 79595   93480       1478.20          524288  2020-12-17 08:54:00           2
# 79596   93481       1478.20          524288  2020-12-17 08:58:00           2
# 79857   93770       2274.10          524288  2020-12-01 14:00:00           2
# ...       ...           ...             ...                  ...         ...
# 89981  106227       1076.66          524288  2020-12-23 17:53:00           2
# 89982  106228       1076.66          524288  2020-12-23 17:47:00           2
# 89983  106229       1076.66          524288  2020-12-23 17:54:00           2
# 89984  106240       1600.00              32  2020-12-23 18:21:00           2
# 89985  106241       1600.00              32  2020-12-23 18:41:00           2
#
#       job_date    day_year
# ...

# %%
damfinal
# Out:
#        job_id  total_amount payment_method             job_time  job_status  \
# 88668  104114       2087.00         524288  2020-12-23 08:21:00           2
# 88669  104115       2087.00         524288  2020-12-23 08:58:00           2
# 88670  104116       2087.00         524288  2020-12-23 09:09:00           2
# 88678  104126       2466.10         524288  2020-12-23 08:36:00           2
# 88679  104127       2466.10         524288  2020-12-23 09:04:00           2
# ...       ...           ...            ...                  ...         ...
# 89981  106227       1076.66         524288  2020-12-23 17:53:00           2
# 89982  106228       1076.66         524288  2020-12-23 17:47:00           2
# 89983  106229       1076.66         524288  2020-12-23 17:54:00           2
# 89984  106240       1600.00             32  2020-12-23 18:21:00           2
# 89985  106241       1600.00             32  2020-12-23 18:41:00           2
#
# ...

# %%
alldecember.to_csv('decemberfinale.csv', index = False)

# %%
damfinal.to_csv('damyfinale.csv', index = False)

# %%
failedtoday['job_date'] = pd.to_datetime(failedtoday['job_time']).dt.to_period('M')

# %%
failedtoday['day_year'] = pd.to_datetime(failedtoday['job_time']).dt.to_period('D')

# %%
canceltoday['job_date'] = pd.to_datetime(canceltoday['job_time']).dt.to_period('M')

# %%
canceltoday['day_year'] = pd.to_datetime(canceltoday['job_time']).dt.to_period('D')

# %%
failedfinal = failedtoday[failedtoday['day_year'] == "2020-12-23"]

# %%
cancelfinal = canceltoday[canceltoday['day_year'] == "2020-12-23"]

# %%
mayorpod['job_date'] = pd.to_datetime(mayorpod['job_time']).dt.to_period('M')

# %%
mayorpod['day_year'] = pd.to_datetime(mayorpod['job_time']).dt.to_period('D')

# %%
mayorcash['job_date'] = pd.to_datetime(mayorcash['job_time']).dt.to_period('M')

# %%
mayorcash['day_year'] = pd.to_datetime(mayorcash['job_time']).dt.to_period('D')

# %%
mayorpaystack['job_date'] = pd.to_datetime(mayorpaystack['job_time']).dt.to_period('M')

# %%
mayorpaystack['day_year'] = pd.to_datetime(mayorpaystack['job_time']).dt.to_period('D')

# %%
mayorpaga['job_date'] = pd.to_datetime(mayorpaga['job_time']).dt.to_period('M')

# %%
mayorpaga['day_year'] = pd.to_datetime(mayorpaga['job_time']).dt.to_period('D')

# %%
mayormonthly['job_date'] = pd.to_datetime(mayormonthly['job_time']).dt.to_period('M')

# %%
mayormonthly['day_year'] = pd.to_datetime(mayormonthly['job_time']).dt.to_period('D')

# %%
damcash['job_date'] = pd.to_datetime(damcash['job_time']).dt.to_period('M')

# %%
damcash['day_year'] = pd.to_datetime(damcash['job_time']).dt.to_period('D')

# %%
damtoh['job_date'] = pd.to_datetime(damtoh['job_time']).dt.to_period('M')

# %%
damtoh['day_year'] = pd.to_datetime(damtoh['job_time']).dt.to_period('D')

# %%
totaldammy= pd.read_csv('finalmayowa.csv')

# %%
totaldammy
# Out:
#      job_id  total_amount  payment_method
# 0    103852        3000.0          262144
# 1    103853        3000.0          262144
# 2    104537        1300.0          262144
# 3    104538        1300.0          262144
# 4    104579        3200.0          262144
# ..      ...           ...             ...
# 533  105003        2500.0          131072
# 534  105075        1900.0          131072
# 535  105076        1900.0          131072
# 536  105175        1700.0          131072
# 537  105176        1700.0          131072
#
# [538 rows x 3 columns]

# %%
damfinal['payment_methodike'] = damfinal['payment_method'].replace([131072, 8],'Paga','Cash')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-12c66c9223c0> in <module>
# ----> 1 damfinal['payment_methodike'] = damfinal['payment_method'].replace([131072, 8],'Paga','Cash')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    4170         method="pad",
#    4171     ):
# -> 4172         return super().replace(
#    4173             to_replace=to_replace,
#    4174             value=value,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    6589         method="pad",
#    6590     ):
# -> 6591         inplace = validate_bool_kwarg(inplace, "inplace")
#    6592         if not is_bool(regex) and to_replace is not None:
# ...

# %%
totaldammy['payment_methodie'] =totaldammy['payment_method'].replace(['8','262144','131072','32','524288'],['Cash','CashonDelivery','Paga','Paystack','MonthlyPayment'.])
# Out:
#   File "<ipython-input-131-da4e9f9098cc>", line 1
#     totaldammy['payment_methodie'] =totaldammy['payment_method'].replace(['8','262144','131072','32','524288'],['Cash','CashonDelivery','Paga','Paystack','MonthlyPayment'.])
#                                                                                                                                                                            ^
# SyntaxError: invalid syntax

# %%
damfinal
# Out:
#        job_id  total_amount payment_method             job_time  job_status  \
# 88668  104114       2087.00         524288  2020-12-23 08:21:00           2
# 88669  104115       2087.00         524288  2020-12-23 08:58:00           2
# 88670  104116       2087.00         524288  2020-12-23 09:09:00           2
# 88678  104126       2466.10         524288  2020-12-23 08:36:00           2
# 88679  104127       2466.10         524288  2020-12-23 09:04:00           2
# ...       ...           ...            ...                  ...         ...
# 89981  106227       1076.66         524288  2020-12-23 17:53:00           2
# 89982  106228       1076.66         524288  2020-12-23 17:47:00           2
# 89983  106229       1076.66         524288  2020-12-23 17:54:00           2
# 89984  106240       1600.00             32  2020-12-23 18:21:00           2
# 89985  106241       1600.00             32  2020-12-23 18:41:00           2
#
# ...

# %%
cancelfinal.to_csv('cancelfinale.csv', index = False)

# %%
totaldammy
# Out:
#      job_id  total_amount payment_method payment_methody payment_methodiy  \
# 0    103852        3000.0         262144          262144           262144
# 1    103853        3000.0         262144          262144           262144
# 2    104537        1300.0         262144          262144           262144
# 3    104538        1300.0         262144          262144           262144
# 4    104579        3200.0         262144          262144           262144
# ..      ...           ...            ...             ...              ...
# 533  105003        2500.0           Paga            Paga             Paga
# 534  105075        1900.0           Paga            Paga             Paga
# 535  105076        1900.0           Paga            Paga             Paga
# 536  105175        1700.0           Paga            Paga             Paga
# 537  105176        1700.0           Paga            Paga             Paga
#
#     payment_methodiay payment_methodiye
# ...

# %%
yorpod = mayorpod[mayorpod['day_year'] == "2020-12-22"]

# %%
yorcash = mayorcash[mayorcash['day_year'] == "2020-12-22"]

# %%
yorpaystack = mayorpaystack[mayorpaystack['day_year'] == "2020-12-22"]

# %%
yorpaga = mayorpaga[mayorpaga['day_year'] == "2020-12-22"]

# %%
yormonthly = mayormonthly[mayormonthly['day_year'] == "2020-12-22"]

# %%
yourpod = yorpod[yorpod['job_status'] == 2]

# %%
yourpod['job_status']
# Out:
# Series([], Name: job_status, dtype: int64)

# %%
dammiecashy = damcash[damcash['day_year'] == "2020-12-20"]

# %%
dammiecash = damcash[damcash['day_year'] == "2020-12-21"]

# %%
dammiecod = damtoh[damtoh['day_year'] == "2020-12-20"]

# %%
dammiecody = damtoh[damtoh['day_year'] == "2020-12-21"]

# %%
test = (yormonthly[['job_id', 'total_amount', 'payment_method']])

# %%
test = dammiecash['job_id']

# %%
test = (dammiecody[['job_id', 'total_amount']])

# %%
testie = pd.DataFrame(test)

# %%
testie
# Out:
#        job_id  total_amount  payment_method
# 30303  104202       1969.80          524288
# 30304  104203       1969.80          524288
# 30416  104539       1417.60          524288
# 30417  104540       1417.60          524288
# 30418  104574       2493.90          524288
# ...       ...           ...             ...
# 30631  105378       1076.66          524288
# 30632  105381       1076.66          524288
# 30633  105382       1076.66          524288
# 30634  105383       1076.66          524288
# 30635  105384       1076.66          524288
#
# [200 rows x 3 columns]

# %%
testie.to_csv('allmonthly.csv', index = False)

# %%
loyaleighteenfd = pd.DataFrame(loyaleighteen)

# %%
listeighteen = loyaleighteenfd[loyaleighteenfd['Card Type'] == "mastercard DEBIT"]

# %%
listeighteen
# Out:
#         Status         Id        Reference Channel  \
# 12     success  208238055    1562141087154    card
# 13     success  209031406     trx_qiy1ljfm    card
# 14     success  209032563  4j4dgz6odqhitnp    card
# 15     success  209633932     trx_up5xstq1    card
# 16     success  209634495  w33gkyejsh2zumd    card
# ...        ...        ...              ...     ...
# 25850  success  927523201  d42zc807tswrfbl    card
# 25851  success  927532381  cirh7ciie56mgh3    card
# 25852  success  927532861  5mu4gqeug0qiw14    card
# 25853  success  927534825  joilgz3ur7maizz    card
# 25854  success  927554534  akm0mnwcqp64oac    card
#
#                        Created At Currency  Amount   Fees  Amount Due  \
# 12      Jul 3rd, 2019 08:04:48 AM      NGN    50.0   0.75       49.25
# 13      Jul 4th, 2019 11:14:49 AM      NGN    50.0   0.75       49.25
# 14      Jul 4th, 2019 11:16:00 AM      NGN   260.0   3.90      256.10
# ...

# %%
listeighteen["Create"] = pd.to_datetime(listeighteen["Created At"])
# Out:
# <ipython-input-11-dbad27ec3dea>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   listeighteen["Create"] = pd.to_datetime(listeighteen["Created At"])

# %%
listeighteen['day_year'] = pd.to_datetime(listeighteen['Created At']).dt.to_period('D')
# Out:
# <ipython-input-12-932199d08316>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   listeighteen['day_year'] = pd.to_datetime(listeighteen['Created At']).dt.to_period('D')

# %%
dayseventeen = listeighteen[listeighteen['day_year'] == "2020-12-17"]

# %%
daythirteen = listfourteen[listfourteen['day_year'] == "2020-12-12"]

# %%
dayfourteen = listfourteen[listfourteen['day_year'] == "2020-12-13"]

# %%
allmasterloyal = listfourteen[(listfourteen['day_year'] > '2020-12-10') & (listfourteen['day_year'] < '2020-12-14')]

# %%
allmasterloyal
# Out:
#         Status         Id        Reference Channel  \
# 24608  success  918621365  1nwpq0sdowc3qeg    card
# 24609  success  918642462     trx_sw0wiiwc    card
# 24610  success  918642854  zswpx3fyht43c2o    card
# 24611  success  918692377  08gtq3x7j09qtzu    card
# 24613  success  918706788  ee9h4hw8mjgiete    card
# ...        ...        ...              ...     ...
# 25039  success  921746379  xewwn663r85j9ix    card
# 25040  success  921853418  19mqyx9udagqiro    card
# 25041  success  921855705     trx_lz1i4umk    card
# 25042  success  921857066  26rfwo7g8drti2d    card
# 25043  success  921923968  9qw1wme19wazl6u    card
#
#                        Created At Currency  Amount   Fees  Amount Due  \
# 24608  Dec 11th, 2020 05:00:28 AM      NGN  2200.0  33.00     2167.00
# 24609  Dec 11th, 2020 05:32:58 AM      NGN    50.0   0.75       49.25
# 24610  Dec 11th, 2020 05:33:37 AM      NGN  1600.0  24.00     1576.00
# ...

# %%
masterseventeen = dayseventeen[dayseventeen['Card Type'] == "mastercard DEBIT"]

# %%
masterseventeen
# Out:
#         Status         Id        Reference Channel  \
# 25528  success  925794327  92vfu7qph2fxet9    card
# 25529  success  925928276     trx_jxztvdi0    card
# 25530  success  925933232  ae5auijis3noxvb    card
# 25531  success  925934625  84zccby4d75qtvf    card
# 25532  success  925936882  cbkfk0k8etr0k6w    card
# ...        ...        ...              ...     ...
# 25736  success  926672740  d5od0qmqn3j2r0v    card
# 25737  success  926678104  zg97vlijxiuo9iq    card
# 25738  success  926742437  7y8h83ltdzeyuqx    card
# 25739  success  926798939  qyzi0gj9b9hohs2    card
# 25740  success  926929464  usrwx53h102qr3p    card
#
#                        Created At Currency  Amount    Fees  Amount Due  \
# 25528  Dec 17th, 2020 12:16:01 AM      NGN  2200.0   33.00     2167.00
# 25529  Dec 17th, 2020 05:27:56 AM      NGN    50.0    0.75       49.25
# 25530  Dec 17th, 2020 05:37:20 AM      NGN  2000.0   30.00     1970.00
# ...

# %%
mailseventeen = masterseventeen["Customer Email"]

# %%
mailseventeen
# Out:
# 25528        nandwani72@yahoo.com
# 25529           osadome@gmail.com
# 25530     ememkarieren2@yahoo.com
# 25531           osadome@gmail.com
# 25532     ememkarieren2@yahoo.com
#                    ...
# 25736     adeosuntobi49@yahoo.com
# 25737       olaoladele8@gmail.com
# 25738        johnizekor@gmail.com
# 25739        subairzee@icloud.com
# 25740    oyeleyetutuola@yahoo.com
# Name: Customer Email, Length: 181, dtype: object

# %%
mailseventeenunique = mailseventeen.unique()

# %%
mailseventeen = pd.DataFrame(mailseventeenunique)

# %%
mailseventeen.to_csv('mailseventeenope.csv', index = False)

# %%
seventeen = pd.read_csv('mailseventeenope.csv')

# %%
bayoseventeen = pd.read_csv('bayomastercardloyalty.csv')

# %%
left = pd.DataFrame(bayoseventeen)

# %%
right = pd.DataFrame(seventeen)

# %%
opeseventeen = pd.merge(left,right,how ='outer', on ='Customer Email')

# %%
opeseventeen
# Out:
#                       Customer Email  Count  Serial
# 0                 abbyoni2@yahoo.com    1.0     1.0
# 1             abianseabasi@gmail.com    2.0     2.0
# 2                adey19866@gmail.com    3.0     3.0
# 3            adeyemobisola@yahoo.com    4.0     4.0
# 4              agwaivictor@gmail.com    5.0     5.0
# ..                               ...    ...     ...
# 732  gourmetfusioncatering@gmail.com    NaN     NaN
# 733               tosinfam@yahoo.com    NaN     NaN
# 734             danisolate@gmail.com    NaN     NaN
# 735            asimiloluwa@yahoo.com    NaN     NaN
# 736             onabanjo50@gmail.com    NaN     NaN
#
# [737 rows x 3 columns]

# %%
opeseventeen.to_csv('mailopeyseventeen.csv', index = False)

# %%
seventeenfinal = pd.read_csv('newopeseventeenfinale.csv')

# %%
left = pd.DataFrame(masterseventeen)

# %%
right = pd.DataFrame(seventeenfinal)

# %%
totalseventeenfinal = pd.merge(left,right,how ='inner', on ='Customer Email')

# %%
totalseventeenfinal.to_csv('totaleseventeenfinale.csv', index = False)

# %%
freshopefifteen = pd.DataFrame(newopeyfifteen)

# %%
mailfifteenunique = mailfifteen.unique()

# %%
mailfifteenunique
# Out:
# array(['f.ajayibembe@gmail.com', 'davanajewelry@gmail.com',
#        'countawo@gmail.com', 'ibiyemi.fashola@gmail.com',
#        'shoerevamp@gmail.com', 'hardey93@gmail.com',
#        'damilolash@gmail.com', 'kenerapu@gmail.com', 'afollabe@gmail.com',
#        'ayinkeyishaladipo@gmail.com', 'urbanestore1@gmail.com',
#        'olaitanyusuph@gmail.com', 'jasonmycroft@gmail.com',
#        'ladywealth8@gmail.com', 'adebara.sulaimon@gmail.com',
#        'yomifaseund@gmail.com', 'angeltaiwo2001@gmail.com',
#        'dejiajila@gmail.com', 'awurumibedubby@gmail.com',
#        'odetolaolajumoke567@gmail.com', 'shalomekelaka@yahoo.com',
#        'folasadey@yahoo.com', 'account@printfactory.com.ng',
#        'oyinkansolamary@gmail.com', 'sallystoresnigltd@gmail.com',
#        'tundeashafa33@yahoo.com', 'pheyishayor@gmail.com',
#        'mimipetti_4@yahoo.com', 'selfitnessng@gmail.com',
#        'steve_fash@hotmail.com', 'dayo.akinwole2010@gmail.com',
# ...

# %%
mailtotalfifteen = pd.DataFrame(mailfifteenunique)

# %%
mailtotalfifteen.to_csv('mailtotalfifteenfinale.csv', index = False)

# %%
loyalsixtwoleft = pd.read_csv('newopesixteenrefined.csv')

# %%
loyalsixtworight = pd.read_csv('newopesixteenrefined.csv')

# %%
loyalright = pd.read_csv('mailtotalfifteenfinale.csv')

# %%
left = pd.DataFrame(loyalsixtwoleft)

# %%
right = pd.DataFrame(mastersixteen)

# %%
opeyfinalsixteentwo = pd.merge(left,right,how ='inner', on ='Customer Email')

# %%
opeyfinalsixteentwo.to_csv('bayosixteentwo.csv', index = False)

# %%
totaltene = pd.read_csv('finaletenloyal.csv')

# %%
loyalleftist = pd.read_csv('bayomastercardloyalty.csv')

# %%
loyalleftist = pd.read_csv('bayomastercardloyalty.csv')

# %%
realbayo = pd.read_csv('simplebayo.csv')

# %%
left = pd.DataFrame(totaleftsixteen)

# %%
right = pd.DataFrame(mastersixteen)

# %%
opeyfinalesixteen = pd.merge(left,right,how ='inner', on ='Customer Email')

# %%
opeyfinalesixteen
# Out:
#                      Customer Email   Status         Id        Reference  \
# 0          tayo.adenmosun@gmail.com  success  923464714  nrqre2wkkgsprx2
# 1              fifedimeji@gmail.com  success  923496773     trx_14brz0a7
# 2              fifedimeji@gmail.com  success  923497000  l47ea9hya03mngj
# 3          funmiscakeshop@gmail.com  success  923512583     trx_swd79ud4
# 4          funmiscakeshop@gmail.com  success  923513206  uncx90p9cdlul98
# 5              tobirin.ba@gmail.com  success  923586945     trx_fylos5jh
# 6              tobirin.ba@gmail.com  success  923590434  11om88sr2cku5up
# 7              tobirin.ba@gmail.com  success  923611934  29j3e9vdxewg3o2
# 8          belloabiodun01@yahoo.com  success  923599621     trx_0p8k94x7
# 9          belloabiodun01@yahoo.com  success  923600493  srs4vqnsx984a96
# 10          girlishshopng@gmail.com  success  923615961     trx_qs7474yd
# 11          girlishshopng@gmail.com  success  923616933  3pq9mjpf61vxqr5
# ...

# %%
opeyfinalesixteen.to_csv('flexopesixteen.csv', index = False)

# %%
opeeleven = opesimpleloyal[opesimpleloyal['day_year'] == "2020-12-11"]

# %%
opetwelve = opesimpleloyal[opesimpleloyal['day_year'] == "2020-12-12"]

# %%
opethirteen = opesimpleloyal[opesimpleloyal['day_year'] == "2020-12-13"]

# %%
opeeleven.to_csv('opeyeleven.csv', index = False)

# %%
opetwelve.to_csv('opeytwelve.csv', index = False)

# %%
opethirteen.to_csv('opeythirteen.csv', index = False)

# %%
simpleloyalall
# Out:
#                Customer Email  Count  Serial
# 0          abbyoni2@yahoo.com    1.0     1.0
# 1      abianseabasi@gmail.com    2.0     2.0
# 2         adey19866@gmail.com    3.0     3.0
# 3     adeyemobisola@yahoo.com    4.0     4.0
# 4       agwaivictor@gmail.com    5.0     5.0
# ..                        ...    ...     ...
# 792      rummiejode@gmail.com    NaN     NaN
# 793         cefoule@gmail.com    NaN     NaN
# 794  chimmarose1990@yahoo.com    NaN     NaN
# 795     ladehector@icloud.com    NaN     NaN
# 796    frank.nkanga@gmail.com    NaN     NaN
#
# [797 rows x 3 columns]

# %%
simpleloyalall.to_csv('mailsimpleloyal.csv', index = False)

# %%
totaltenloyalall.to_csv('mailfinaltotalten.csv', index = False)

# %%
tenloyal.to_csv('mailfinaletenloyal.csv', index = False)

# %%
tenloyal
# Out:
#                  Customer Email  Count  Serial
# 0            abbyoni2@yahoo.com    1.0     1.0
# 1        abianseabasi@gmail.com    2.0     2.0
# 2           adey19866@gmail.com    3.0     3.0
# 3       adeyemobisola@yahoo.com    4.0     4.0
# 4         agwaivictor@gmail.com    5.0     5.0
# ..                          ...    ...     ...
# 525        bakwaibags@gmail.com    NaN     NaN
# 526      ashlieanozie@gmail.com    NaN     NaN
# 527   titilayoadeogun@gmail.com    NaN     NaN
# 528           beampeh@gmail.com    NaN     NaN
# 529  oseniabdulraheem@gmail.com    NaN     NaN
#
# [530 rows x 3 columns]

# %%
mailtene.to_csv('mailteneloyal.csv', index = False)

# %%
mailtene
# Out:
#                               0
# 0       bolarinwaajao@gmail.com
# 1            seunaros@yahoo.com
# 2     adedoyin.omirin@gmail.com
# 3        tangooscar02@yahoo.com
# 4        generaljunee@gmail.com
# ..                          ...
# 85  consistentolusesi@gmail.com
# 86  chatwanigordhan01@gmail.com
# 87         imanbisade@gmail.com
# 88   oseniabdulraheem@gmail.com
# 89    adesinapelumi23@gmail.com
#
# [90 rows x 1 columns]

# %%
mailfirst.to_csv('masterfirst.csv', index = False)

# %%
mailnineunique = mailnine.unique()

# %%
mailninety = pd.DataFrame(mailnineunique)

# %%
mailninety
# Out:
#                                0
# 0               edivri@gmail.com
# 1           sammi.giwa@gmail.com
# 2          lolademajek@gmail.com
# 3         generaljunee@gmail.com
# 4   kwiknigerialimited@gmail.com
# ..                           ...
# 72          vincecraw4@gmail.com
# 73            mskems14@gmail.com
# 74          sbolanle30@gmail.com
# 75         mosopealuko@yahoo.com
# 76          ore.ire.16@gmail.com
#
# [77 rows x 1 columns]

# %%
dailyloyal = pd.read_csv('combinedailyloyaltymails.csv')

# %%
refinednine = pd.read_csv('refinedloyalnine.csv')

# %%
left = pd.DataFrame(refinednine)

# %%
right = pd.DataFrame(masternine)

# %%
finalenineloyal = pd.merge(left,right,how ='inner', on ='Customer Email')

# %%
finalenineloyal
# Out:
#                      Customer Email   Status         Id        Reference  \
# 0             lolademajek@gmail.com  success  916144673  nmezwg5g7u0i2mf
# 1               dejiajila@gmail.com  success  916197226  pqxjp0n02w7xa3y
# 2         opeyemiabiona42@gmail.com  success  916215939  cck5r2vby0ven7y
# 3             tolsky4life@gmail.com  success  916227493     trx_yak19gtr
# 4             tolsky4life@gmail.com  success  916228364  5myykjubjlm0aa8
# 5              gracenet10@gmail.com  success  916232653     trx_0t60nt38
# 6              gracenet10@gmail.com  success  916233792  oggr9l24p91g930
# 7                  sayomi@gmail.com  success  916265778  x8pmeek448cr6pl
# 8         dayo.fidoltrips@gmail.com  success  916274176     trx_et4px0i2
# 9         dayo.fidoltrips@gmail.com  success  916276125  b4kcl1ndwc4dhj3
# 10           steve_fash@hotmail.com  success  916297992  95yzhsr0lybwk1r
# 11           info.sooopro@yahoo.com  success  916301555  zcustpq19w44shd
# ...

# %%
finalenineloyal.to_csv('finalenineloyal.csv', index = False)

# %%
refinednine
# Out:
#                      Customer Email
# 0             lolademajek@gmail.com
# 1               dejiajila@gmail.com
# 2         opeyemiabiona42@gmail.com
# 3             tolsky4life@gmail.com
# 4              gracenet10@gmail.com
# 5                  sayomi@gmail.com
# 6         dayo.fidoltrips@gmail.com
# 7            steve_fash@hotmail.com
# 8            info.sooopro@yahoo.com
# 9               damiie99@icloud.com
# 10          tracyakpofure@yahoo.com
# 11        jessicaozoemena@gmail.com
# 12         paulmarthmedia@gmail.com
# 13        omosalewabadejo@gmail.com
# 14             jzofashion@gmail.com
# 15          rajnmariam1@yahoo.co.uk
# 16            scentsluxe5@gmail.com
# 17          mohammedayuba@yahoo.com
# 18                aiwaxes@yahoo.com
# 19             imanbisade@gmail.com
# 20              nikkyi643@gmail.com
# 21             metizgrill@gmail.com
# 22         onaopemipodara@gmail.com
# 23        gobinddaswanigd@gmail.com
# 24         enechukwuodiri@yahoo.com
# ...

# %%
nineloyal = pd.read_csv('masternineunik.csv')

# %%
dailyloyal
# Out:
#               Customer Email  Count  Serial
# 0         abbyoni2@yahoo.com      1       1
# 1     abianseabasi@gmail.com      2       2
# 2        adey19866@gmail.com      3       3
# 3    adeyemobisola@yahoo.com      4       4
# 4      agwaivictor@gmail.com      5       5
# ..                       ...    ...     ...
# 495                      NaN    496     496
# 496                      NaN    497     497
# 497                      NaN    498     498
# 498                      NaN    499     499
# 499                      NaN    500     500
#
# [500 rows x 3 columns]

# %%
left = pd.DataFrame(dailyloyal)

# %%
right = pd.DataFrame(nineloyal)

# %%
right
# Out:
#                   Customer Email
# 0               edivri@gmail.com
# 1           sammi.giwa@gmail.com
# 2          lolademajek@gmail.com
# 3         generaljunee@gmail.com
# 4   kwiknigerialimited@gmail.com
# ..                           ...
# 72          vincecraw4@gmail.com
# 73            mskems14@gmail.com
# 74          sbolanle30@gmail.com
# 75         mosopealuko@yahoo.com
# 76          ore.ire.16@gmail.com
#
# [77 rows x 1 columns]

# %%
fullnineloyal = pd.merge(left,right,how ='outer', on ='Customer Email')

# %%
fullnineloyal
# Out:
#               Customer Email  Count  Serial
# 0         abbyoni2@yahoo.com    1.0     1.0
# 1     abianseabasi@gmail.com    2.0     2.0
# 2        adey19866@gmail.com    3.0     3.0
# 3    adeyemobisola@yahoo.com    4.0     4.0
# 4      agwaivictor@gmail.com    5.0     5.0
# ..                       ...    ...     ...
# 530         okjaox@gmail.com    NaN     NaN
# 531    asuzunnenna@gmail.com    NaN     NaN
# 532     sbolanle30@gmail.com    NaN     NaN
# 533    mosopealuko@yahoo.com    NaN     NaN
# 534     ore.ire.16@gmail.com    NaN     NaN
#
# [535 rows x 3 columns]

# %%
fullnineloyal.to_csv('finalnineloyal.csv', index = False)

# %%
mailninety.to_csv('masternineunik.csv', index = False)

# %%
mailall = mailfirst

# %%
mailfirstunique = mailfirst.unique()

# %%
mailfirstunique
# Out:
# array(['edivri@gmail.com', 'ozone14800@yahoo.com',
#        'folusoajayi01@gmail.com', 'lawatonyema@gmail.com',
#        'adey19866@gmail.com', 'sammi.giwa@gmail.com',
#        'abianseabasi@gmail.com', 'kheeraholawepo@gmail.com',
#        'info.lagosfoodcity@gmail.com', 'sharonstephen1@hotmail.com',
#        'cravatservices@gmail.com', 'ejike.ebonybet@gmail.com',
#        'cornejike88@gmail.com', 'shalomekelaka@yahoo.com',
#        'yomillion1993@gmail.com', 'abbyoni2@yahoo.com',
#        'bayonlehassan@gmail.com', 'pheezahtrendyclothing@gmail.com',
#        'imezphilus@yahoo.com', 'vanillavickky90@gmail.com',
#        'deoladeyemo23@gmail.com', 'babawale.arabambi@gmail.com',
#        'dingsurfing@gmail.com', 'ivie.olotu@icloud.com',
#        'seunaros@yahoo.com', 'mhzbhola@gmail.com', 'okufoniyi@icloud.com',
#        'sehara4luv@gmail.com', 'adeyemobisola@yahoo.com',
#        'splendorbymo@outlook.com', 'rotimi.lopez@gmail.com',
# ...

# %%
daysecond = totalist[totalist['day_year'] == "2020-12-02"]

# %%
mastersecond = daysecond[daysecond['Card Type'] == "mastercard DEBIT"]

# %%
mailsecond = mastersecond["Customer Email"]

# %%
mailsecondunique = mailsecond.unique()

# %%
mastersecondunique = pd.DataFrame(mailsecondunique)

# %%
mastersecondunique.to_csv('mastersecondunique.csv', index = False)

# %%
masteroneunique = pd.DataFrame(mailfirstunique)

# %%
mailsecondunique = mailfirst.unique()

# %%
masteroneunique
# Out:
#                             0
# 0            edivri@gmail.com
# 1        ozone14800@yahoo.com
# 2     folusoajayi01@gmail.com
# 3       lawatonyema@gmail.com
# 4         adey19866@gmail.com
# ..                        ...
# 56           kenny@medsaf.com
# 57       esejam2000@yahoo.com
# 58  favourdamilola1@gmail.com
# 59    topeomotayo80@yahoo.com
# 60      olaoladele8@gmail.com
#
# [61 rows x 1 columns]

# %%
masteroneunique.to_csv('masterfirstunique.csv', index = False)

# %%
daythird = totalist[totalist['day_year'] == "2020-12-03"]

# %%
masterthird = daythird[daythird['Card Type'] == "mastercard DEBIT"]

# %%
mailthird = masterthird["Customer Email"]

# %%
mailthirdunique = mailthird.unique()

# %%
masterthirdunique = pd.DataFrame(mailthirdunique)

# %%
masterthirdunique.to_csv('masterthirdunique.csv', index = False)

# %%
dayfourth = totalist[totalist['day_year'] == "2020-12-04"]

# %%
masterfourth = dayfourth[dayfourth['Card Type'] == "mastercard DEBIT"]

# %%
mailfourth = masterfourth["Customer Email"]

# %%
mailfourthunique = mailfourth.unique()

# %%
masterfourthunique = pd.DataFrame(mailfourthunique)

# %%
masterfourthunique.to_csv('masterfourthunique.csv', index = False)

# %%
dayfifth = totalist[totalist['day_year'] == "2020-12-05"]

# %%
masterfifth = dayfifth[dayfifth['Card Type'] == "mastercard DEBIT"]

# %%
mailfifth = masterfifth["Customer Email"]

# %%
mailfifthunique = mailfifth.unique()

# %%
masterfifthunique = pd.DataFrame(mailfifthunique)

# %%
masterfifthunique.to_csv('masterfifthunique.csv', index = False)
