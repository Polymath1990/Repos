# %%
pwd
# Out:
# 'C:\\Users\\bayo'

# %%
import pandas as pd

# %%
import pandas as pd

Bee = pd.read_csv("Mall_Customers.csv")

# %%
buz = pd.DataFrame(Bee)

# %%
buz['Age']
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 195    False
# 196     True
# 197    False
# 198    False
# 199    False
# Name: Age, Length: 200, dtype: bool

# %%
print(Bee)
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
Bee.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
Bee_xlsx = pd.read_excel("Dominoh.xlsx")

# %%
print(Bee_xlsx. head(5))
# Out:
#    S/N       Date   Branch    Pizza Sold  Price  Quantity  Sales      Time
# 0    1 2015-12-11   Ibadan       Meatzaa   2000         5  10000  08:00:01
# 1    2 2015-12-14    Ikoyi  Extravaganza   2000         4   8000  08:00:02
# 2    3 2015-12-04    Lekki   BBQ Chicken   4000         5  20000  08:00:04
# 3    4 2015-12-14    Ikoyi  Extravaganza   2000         1   2000  08:00:07
# 4    5 2015-12-07  Gbagada       Meatzaa   2000         4   8000  08:00:08

# %%
print(Bee_xlsx.tail(5))
# Out:
#        S/N       Date    Branch      Pizza Sold  Price  Quantity  Sales  \
# 4995  4996 2015-12-13     Lekki       Margarita   4000         1   4000
# 4996  4997 2015-12-07  Surulere       Beef Suya   3000         5  15000
# 4997  4998 2015-12-07     Ikoyi  Pepperoni Suya   3000         4  12000
# 4998  4999 2015-12-08   Gbagada        Italiano   3000         1   3000
# 4999  5000 2015-12-10     Ikoyi       Beef Suya   3000         5  15000
#
#           Time
# 4995  09:42:28
# 4996  09:42:31
# 4997  09:42:32
# 4998  09:42:32
# 4999  09:42:33

# %%
print(Bee.columns)
# Out:
# Index(['CustomerID', 'Genre', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
print(Bee[['Age', 'Genre','CustomerID']])
# Out:
#      Age   Genre  CustomerID
# 0     19    Male           1
# 1     21    Male           2
# 2     20  Female           3
# 3     23  Female           4
# 4     31  Female           5
# ..   ...     ...         ...
# 195   35  Female         196
# 196   45  Female         197
# 197   32    Male         198
# 198   32    Male         199
# 199   30    Male         200
#
# [200 rows x 3 columns]

# %%
print(Bee.iloc[1:4])
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77

# %%
Bee_xlsx.loc[Bee_xlsx['Branch'] == "Lekki"]
# Out:
#        S/N       Date Branch      Pizza Sold  Price  Quantity  Sales      Time
# 2        3 2015-12-04  Lekki     BBQ Chicken   4000         5  20000  08:00:04
# 10      11 2015-12-12  Lekki  Chicken Legend   2000         5  10000  08:00:26
# 15      16 2015-12-07  Lekki       Beef Suya   3000         5  15000  08:00:34
# 17      18 2015-12-14  Lekki      Hot Veggie   4000         5  20000  08:00:35
# 20      21 2015-12-06  Lekki       Margarita   4000         3  12000  08:00:37
# ...    ...        ...    ...             ...    ...       ...    ...       ...
# 4985  4986 2015-12-13  Lekki     BBQ Chicken   4000         4  16000  09:42:13
# 4986  4987 2015-12-09  Lekki        Italiano   3000         2   6000  09:42:14
# 4992  4993 2015-12-10  Lekki     BBQ Chicken   4000         4  16000  09:42:26
# 4994  4995 2015-12-04  Lekki    Chicken Suya   4000         4  16000  09:42:28
# 4995  4996 2015-12-13  Lekki       Margarita   4000         1   4000  09:42:28
#
# [968 rows x 8 columns]

# %%
Bee_xlsx.loc[Bee_xlsx['Price'] == '4000']
# Out:
# Empty DataFrame
# Columns: [S/N, Date, Branch, Pizza Sold, Price, Quantity, Sales, Time]
# Index: []

# %%
Bee_xlsx.describe()
# Out:
#                S/N        Price     Quantity         Sales
# count  5000.000000  5000.000000  5000.000000   5000.000000
# mean   2500.500000  3136.400000     3.010000   9474.000000
# std    1443.520003   846.367714     1.412763   5305.558763
# min       1.000000  2000.000000     1.000000   2000.000000
# 25%    1250.750000  2000.000000     2.000000   4000.000000
# 50%    2500.500000  3000.000000     3.000000   8000.000000
# 75%    3750.250000  4000.000000     4.000000  12000.000000
# max    5000.000000  4000.000000     5.000000  20000.000000

# %%
Bee_xlsx.sort_values(['Sales', 'Price'],ascending =[0,1])
# Out:
#        S/N       Date   Branch        Pizza Sold  Price  Quantity  Sales  \
# 2        3 2015-12-04    Lekki       BBQ Chicken   4000         5  20000
# 6        7 2015-12-04   Ibadan  BBQ Philly Steak   4000         5  20000
# 9       10 2015-12-04   Ibadan      Chicken Suya   4000         5  20000
# 17      18 2015-12-14    Lekki        Hot Veggie   4000         5  20000
# 38      39 2015-12-14   Ibadan   Pepperoni Feast   4000         5  20000
# ...    ...        ...      ...               ...    ...       ...    ...
# 4930  4931 2015-12-15  Gbagada           Meatzaa   2000         1   2000
# 4960  4961 2015-12-07   Ibadan      Chicken Bali   2000         1   2000
# 4971  4972 2015-12-14  Gbagada      Chicken Bali   2000         1   2000
# 4975  4976 2015-12-06    Lekki           Meatzaa   2000         1   2000
# 4978  4979 2015-12-09    Lekki      Chicken Bali   2000         1   2000
#
#           Time
# 2     08:00:04
# 6     08:00:20
# 9     08:00:25
# 17    08:00:35
# ...

# %%
Bee_xlsx.head(5)
# Out:
#    S/N       Date   Branch    Pizza Sold  Price  Quantity      Time
# 0    1 2015-12-11   Ibadan       Meatzaa   2000         5  08:00:01
# 1    2 2015-12-14    Ikoyi  Extravaganza   2000         4  08:00:02
# 2    3 2015-12-04    Lekki   BBQ Chicken   4000         5  08:00:04
# 3    4 2015-12-14    Ikoyi  Extravaganza   2000         1  08:00:07
# 4    5 2015-12-07  Gbagada       Meatzaa   2000         4  08:00:08

# %%
Bee_xlsx.head(5)
Bee_xlsx= Bee_xlsx.drop(columns=['Revenue'])

# %%
Bee_xlsx.head(5)
# Out:
#    S/N       Date   Branch    Pizza Sold  Price  Quantity      Time
# 0    1 2015-12-11   Ibadan       Meatzaa   2000         5  08:00:01
# 1    2 2015-12-14    Ikoyi  Extravaganza   2000         4  08:00:02
# 2    3 2015-12-04    Lekki   BBQ Chicken   4000         5  08:00:04
# 3    4 2015-12-14    Ikoyi  Extravaganza   2000         1  08:00:07
# 4    5 2015-12-07  Gbagada       Meatzaa   2000         4  08:00:08

# %%
Bee_xlsx['Revenue'] = Bee_xlsx['Price'] * Bee_xlsx['Quantity']
Bee_xlsx.head(5)
# Out:
#    S/N       Date   Branch    Pizza Sold  Price  Quantity      Time  Revenue
# 0    1 2015-12-11   Ibadan       Meatzaa   2000         5  08:00:01    10000
# 1    2 2015-12-14    Ikoyi  Extravaganza   2000         4  08:00:02     8000
# 2    3 2015-12-04    Lekki   BBQ Chicken   4000         5  08:00:04    20000
# 3    4 2015-12-14    Ikoyi  Extravaganza   2000         1  08:00:07     2000
# 4    5 2015-12-07  Gbagada       Meatzaa   2000         4  08:00:08     8000

# %%
by =Bee_xlsx

# %%
bx.head(5)
# Out:
#    S/N       Date   Branch    Pizza Sold  Price  Quantity      Time  Revenue
# 0    1 2015-12-11   Ibadan       Meatzaa   2000         5  08:00:01    10000
# 1    2 2015-12-14    Ikoyi  Extravaganza   2000         4  08:00:02     8000
# 2    3 2015-12-04    Lekki   BBQ Chicken   4000         5  08:00:04    20000
# 3    4 2015-12-14    Ikoyi  Extravaganza   2000         1  08:00:07     2000
# 4    5 2015-12-07  Gbagada       Meatzaa   2000         4  08:00:08     8000

# %%
bx['Snap'] = bx.iloc[:,4:6].sum(1)

# %%
bx.head(7)
# Out:
#    S/N       Date    Branch        Pizza Sold  Price  Quantity      Time  \
# 0    1 2015-12-11    Ibadan           Meatzaa   2000         5  08:00:01
# 1    2 2015-12-14     Ikoyi      Extravaganza   2000         4  08:00:02
# 2    3 2015-12-04     Lekki       BBQ Chicken   4000         5  08:00:04
# 3    4 2015-12-14     Ikoyi      Extravaganza   2000         1  08:00:07
# 4    5 2015-12-07   Gbagada           Meatzaa   2000         4  08:00:08
# 5    6 2015-12-08  Surulere        Hot Veggie   4000         2  08:00:14
# 6    7 2015-12-04    Ibadan  BBQ Philly Steak   4000         5  08:00:20
#
#    Revenue  Snap
# 0    10000  2005
# 1     8000  2004
# 2    20000  4005
# 3     2000  2001
# 4     8000  2004
# 5     8000  4002
# 6    20000  4005

# %%
cols=list (bx.columns)
bx = bx[cols[0:4] + [cols[-1]]+ cols[4:9]]

# %%
bx.drop('Snap')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b4248c501e33> in <module>
# ----> 1 bx.drop('Snap')
#
# NameError: name 'bx' is not defined

# %%
by.head(6)
# Out:
#    S/N       Date    Branch    Pizza Sold  Price  Quantity      Time  Revenue  \
# 0    1 2015-12-11    Ibadan       Meatzaa   2000         5  08:00:01    10000
# 1    2 2015-12-14     Ikoyi  Extravaganza   2000         4  08:00:02     8000
# 2    3 2015-12-04     Lekki   BBQ Chicken   4000         5  08:00:04    20000
# 3    4 2015-12-14     Ikoyi  Extravaganza   2000         1  08:00:07     2000
# 4    5 2015-12-07   Gbagada       Meatzaa   2000         4  08:00:08     8000
# 5    6 2015-12-08  Surulere    Hot Veggie   4000         2  08:00:14     8000
#
#    Snap
# 0  2005
# 1  2004
# 2  4005
# 3  2001
# 4  2004
# 5  4002

# %%
by.to_csv('modified.csv', index = False)
by.to_excel('modofied.xlsx', index = False)
by.to_csv('modified.txt', index = False, sep='\t')

# %%
by.loc[(by['Branch'] =='Ikoyi') & (by['Revenue'] == 20000)]
# Out:
#        S/N       Date Branch           Pizza Sold  Price  Quantity      Time  \
# 143    144 2015-12-15  Ikoyi      Pepperoni Feast   4000         5  08:04:35
# 165    166 2015-12-15  Ikoyi            Margarita   4000         5  08:05:12
# 214    215 2015-12-11  Ikoyi          BBQ Chicken   4000         5  08:06:46
# 241    242 2015-12-08  Ikoyi          BBQ Chicken   4000         5  08:07:28
# 309    310 2015-12-06  Ikoyi     BBQ Philly Steak   4000         5  08:09:47
# ...    ...        ...    ...                  ...    ...       ...       ...
# 4718  4719 2015-12-10  Ikoyi  Hot Pepperoni Feast   4000         5  09:38:04
# 4773  4774 2015-12-05  Ikoyi  Hot Pepperoni Feast   4000         5  09:38:44
# 4804  4805 2015-12-07  Ikoyi           Hot Veggie   4000         5  09:39:11
# 4814  4815 2015-12-08  Ikoyi          BBQ Chicken   4000         5  09:39:20
# 4900  4901 2015-12-15  Ikoyi            Margarita   4000         5  09:40:29
#
#       Revenue  Snap
# 143     20000  4005
# ...

# %%
by.loc[by['Pizza Sold'].str.contains('Chicken')]
# Out:
#        S/N       Date    Branch      Pizza Sold  Price  Quantity      Time  \
# 2        3 2015-12-04     Lekki     BBQ Chicken   4000         5  08:00:04
# 7        8 2015-12-07     Ikoyi   Chicken Feast   2000         1  08:00:20
# 9       10 2015-12-04    Ibadan    Chicken Suya   4000         5  08:00:25
# 10      11 2015-12-12     Lekki  Chicken Legend   2000         5  08:00:26
# 12      13 2015-12-15   Gbagada    Chicken Suya   4000         2  08:00:29
# ...    ...        ...       ...             ...    ...       ...       ...
# 4983  4984 2015-12-11  Surulere     BBQ Chicken   4000         4  09:42:12
# 4985  4986 2015-12-13     Lekki     BBQ Chicken   4000         4  09:42:13
# 4988  4989 2015-12-14   Gbagada     BBQ Chicken   4000         3  09:42:15
# 4992  4993 2015-12-10     Lekki     BBQ Chicken   4000         4  09:42:26
# 4994  4995 2015-12-04     Lekki    Chicken Suya   4000         4  09:42:28
#
#       Revenue  Snap
# 2       20000  4005
# 7        2000  2001
# ...

# %%
import re
by.loc[by['Branch'].str.contains('Lekki|Ikoyi', regex = True)]
# Out:
#        S/N       Date Branch      Pizza Sold  Price  Quantity      Time  \
# 1        2 2015-12-14  Ikoyi    Extravaganza   2000         4  08:00:02
# 2        3 2015-12-04  Lekki     BBQ Chicken   4000         5  08:00:04
# 3        4 2015-12-14  Ikoyi    Extravaganza   2000         1  08:00:07
# 7        8 2015-12-07  Ikoyi   Chicken Feast   2000         1  08:00:20
# 10      11 2015-12-12  Lekki  Chicken Legend   2000         5  08:00:26
# ...    ...        ...    ...             ...    ...       ...       ...
# 4993  4994 2015-12-10  Ikoyi       Beef Suya   3000         3  09:42:27
# 4994  4995 2015-12-04  Lekki    Chicken Suya   4000         4  09:42:28
# 4995  4996 2015-12-13  Lekki       Margarita   4000         1  09:42:28
# 4997  4998 2015-12-07  Ikoyi  Pepperoni Suya   3000         4  09:42:32
# 4999  5000 2015-12-10  Ikoyi       Beef Suya   3000         5  09:42:33
#
#       Revenue  Snap
# 1        8000  2004
# 2       20000  4005
# 3        2000  2001
# ...

# %%
by.loc[by['Pizza Sold'].str.contains('^Chi[a-z]*', regex = True)]
# Out:
#        S/N       Date    Branch      Pizza Sold  Price  Quantity      Time  \
# 7        8 2015-12-07     Ikoyi   Chicken Feast   2000         1  08:00:20
# 9       10 2015-12-04    Ibadan    Chicken Suya   4000         5  08:00:25
# 10      11 2015-12-12     Lekki  Chicken Legend   2000         5  08:00:26
# 12      13 2015-12-15   Gbagada    Chicken Suya   4000         2  08:00:29
# 13      14 2015-12-11    Ibadan   Chicken Feast   2000         5  08:00:33
# ...    ...        ...       ...             ...    ...       ...       ...
# 4965  4966 2015-12-03   Gbagada  Chicken Legend   2000         4  09:41:52
# 4967  4968 2015-12-03  Surulere    Chicken Suya   4000         5  09:41:53
# 4971  4972 2015-12-14   Gbagada    Chicken Bali   2000         1  09:41:59
# 4978  4979 2015-12-09     Lekki    Chicken Bali   2000         1  09:42:08
# 4994  4995 2015-12-04     Lekki    Chicken Suya   4000         4  09:42:28
#
#       Revenue  Snap
# 7        2000  2001
# 9       20000  4005
# ...

# %%
by.loc[by['Pizza Sold'] == 'Extravaganza', 'Pizza Sold']= 'Yummy'

# %%
by
# Out:
#        S/N       Date    Branch      Pizza Sold  Price  Quantity      Time  \
# 0        1 2015-12-11    Ibadan         Meatzaa   2000         5  08:00:01
# 1        2 2015-12-14     Ikoyi           Yummy   2000         4  08:00:02
# 2        3 2015-12-04     Lekki     BBQ Chicken   4000         5  08:00:04
# 3        4 2015-12-14     Ikoyi           Yummy   2000         1  08:00:07
# 4        5 2015-12-07   Gbagada         Meatzaa   2000         4  08:00:08
# ...    ...        ...       ...             ...    ...       ...       ...
# 4995  4996 2015-12-13     Lekki       Margarita   4000         1  09:42:28
# 4996  4997 2015-12-07  Surulere       Beef Suya   3000         5  09:42:31
# 4997  4998 2015-12-07     Ikoyi  Pepperoni Suya   3000         4  09:42:32
# 4998  4999 2015-12-08   Gbagada        Italiano   3000         1  09:42:32
# 4999  5000 2015-12-10     Ikoyi       Beef Suya   3000         5  09:42:33
#
#       Revenue  Snap
# 0       10000  2005
# 1        8000  2004
# ...

# %%
by.loc[by['Pizza Sold'] == 'Yummy', 'Snap']= 2010

# %%
by
# Out:
#        S/N       Date    Branch      Pizza Sold  Price  Quantity      Time  \
# 0        1 2015-12-11    Ibadan         Meatzaa   2000         5  08:00:01
# 1        2 2015-12-14     Ikoyi           Yummy   2000         4  08:00:02
# 2        3 2015-12-04     Lekki     BBQ Chicken   4000         5  08:00:04
# 3        4 2015-12-14     Ikoyi           Yummy   2000         1  08:00:07
# 4        5 2015-12-07   Gbagada         Meatzaa   2000         4  08:00:08
# ...    ...        ...       ...             ...    ...       ...       ...
# 4995  4996 2015-12-13     Lekki       Margarita   4000         1  09:42:28
# 4996  4997 2015-12-07  Surulere       Beef Suya   3000         5  09:42:31
# 4997  4998 2015-12-07     Ikoyi  Pepperoni Suya   3000         4  09:42:32
# 4998  4999 2015-12-08   Gbagada        Italiano   3000         1  09:42:32
# 4999  5000 2015-12-10     Ikoyi       Beef Suya   3000         5  09:42:33
#
#       Revenue  Snap
# 0       10000  2005
# 1        8000  2010
# ...

# %%
by.loc[by['Revenue'] >=19000, ['Snap']]= 5000

# %%
by
# Out:
#        S/N       Date    Branch      Pizza Sold  Price  Quantity      Time  \
# 0        1 2015-12-11    Ibadan         Meatzaa   2000         5  08:00:01
# 1        2 2015-12-14     Ikoyi           Yummy   2000         4  08:00:02
# 2        3 2015-12-04     Lekki     BBQ Chicken   4000         5  08:00:04
# 3        4 2015-12-14     Ikoyi           Yummy   2000         1  08:00:07
# 4        5 2015-12-07   Gbagada         Meatzaa   2000         4  08:00:08
# ...    ...        ...       ...             ...    ...       ...       ...
# 4995  4996 2015-12-13     Lekki       Margarita   4000         1  09:42:28
# 4996  4997 2015-12-07  Surulere       Beef Suya   3000         5  09:42:31
# 4997  4998 2015-12-07     Ikoyi  Pepperoni Suya   3000         4  09:42:32
# 4998  4999 2015-12-08   Gbagada        Italiano   3000         1  09:42:32
# 4999  5000 2015-12-10     Ikoyi       Beef Suya   3000         5  09:42:33
#
#       Revenue  Snap
# 0       10000  3000
# 1        8000  3000
# ...

# %%
by.groupby(['Branch']).mean().sort_values('Revenue', ascending = False)
# Out:
#                   S/N        Price  Quantity      Revenue         Snap
# Branch
# Lekki     2455.842975  3153.925620  3.040289  9641.528926  3159.590909
# Surulere  2545.069767  3137.420719  3.027484  9483.086681  3132.641649
# Ibadan    2495.543086  3121.242485  3.018036  9469.939880  3161.824649
# Gbagada   2490.072604  3124.878993  3.013553  9467.570184  3132.150048
# Ikoyi     2516.408531  3145.023697  2.955450  9322.274882  3156.957346

# %%
by.groupby(['Pizza Sold']).mean().sort_values('Revenue', ascending = False)
# Out:
#                              S/N   Price  Quantity       Revenue         Snap
# Pizza Sold
# Hot Pepperoni Feast  2464.023739  4000.0  3.183976  12735.905045  3667.813056
# BBQ Philly Steak     2347.166113  4000.0  3.162791  12651.162791  3591.508306
# Chicken Suya         2472.884244  4000.0  3.073955  12295.819936  3607.893891
# Margarita            2511.834507  4000.0  3.066901  12267.605634  3662.183099
# Hot Veggie           2480.481481  4000.0  2.932099  11728.395062  3617.493827
# Pepperoni Feast      2476.932476  4000.0  2.916399  11665.594855  3614.356913
# BBQ Chicken          2426.190323  4000.0  2.903226  11612.903226  3613.135484
# Beef Suya            2602.270701  3000.0  3.124204   9372.611465  3000.191083
# Veggie Supreme       2499.753799  3000.0  3.066869   9200.607903  3000.164134
# Pepperoni Suya       2600.092697  3000.0  3.025281   9075.842697  3000.188202
# Italiano             2566.480122  3000.0  3.012232   9036.697248  3000.192661
# ...

# %%
by['count']=1
by.groupby(['Pizza Sold', 'Branch']).count()['count']
# Out:
# Pizza Sold   Branch
# BBQ Chicken  Gbagada     66
#              Ibadan      56
#              Ikoyi       65
#              Lekki       59
#              Surulere    64
#                          ..
# Yummy        Gbagada     65
#              Ibadan      56
#              Ikoyi       58
#              Lekki       63
#              Surulere    54
# Name: count, Length: 80, dtype: int64

# %%
print(Bee)
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
for boss in pd.read_csv("Modified.csv", chunksize=5):
    print("CHUNK BOSS")
    print(boss)
# Out:
# CHUNK BOSS
#    S/N        Date   Branch    Pizza Sold  Price  Quantity      Time  Revenue  \
# 0    1  2015-12-11   Ibadan       Meatzaa   2000         5  08:00:01    10000
# 1    2  2015-12-14    Ikoyi  Extravaganza   2000         4  08:00:02     8000
# 2    3  2015-12-04    Lekki   BBQ Chicken   4000         5  08:00:04    20000
# 3    4  2015-12-14    Ikoyi  Extravaganza   2000         1  08:00:07     2000
# 4    5  2015-12-07  Gbagada       Meatzaa   2000         4  08:00:08     8000
#
#    Snap
# 0  2005
# 1  2004
# 2  4005
# 3  2001
# 4  2004
# CHUNK BOSS
#    S/N        Date    Branch        Pizza Sold  Price  Quantity      Time  \
# 5    6  2015-12-08  Surulere        Hot Veggie   4000         2  08:00:14
# 6    7  2015-12-04    Ibadan  BBQ Philly Steak   4000         5  08:00:20
# 7    8  2015-12-07     Ikoyi     Chicken Feast   2000         1  08:00:20
# 8    9  2015-12-07   Gbagada           Meatzaa   2000         3  08:00:22
# ...

# %%
real_boss = pd.DataFrame(columns =boss.columns)

for boss in pd.read_csv("Modified.csv", chunksize=5):
    results = boss.groupby(['Branch']).mean()
    real_boss = pd.concat([real_boss, results], sort = False)
    print(real_boss)
# Out:
#          S/N Date Branch Pizza Sold   Price  Quantity Time  Revenue    Snap
# Gbagada  5.0  NaN    NaN        NaN  2000.0       4.0  NaN   8000.0  2004.0
# Ibadan   1.0  NaN    NaN        NaN  2000.0       5.0  NaN  10000.0  2005.0
# Ikoyi    3.0  NaN    NaN        NaN  2000.0       2.5  NaN   5000.0  2002.5
# Lekki    3.0  NaN    NaN        NaN  4000.0       5.0  NaN  20000.0  4005.0
#           S/N Date Branch Pizza Sold   Price  Quantity Time  Revenue    Snap
# Gbagada   5.0  NaN    NaN        NaN  2000.0       4.0  NaN   8000.0  2004.0
# Ibadan    1.0  NaN    NaN        NaN  2000.0       5.0  NaN  10000.0  2005.0
# Ikoyi     3.0  NaN    NaN        NaN  2000.0       2.5  NaN   5000.0  2002.5
# Lekki     3.0  NaN    NaN        NaN  4000.0       5.0  NaN  20000.0  4005.0
# Gbagada   9.0  NaN    NaN        NaN  2000.0       3.0  NaN   6000.0  2003.0
# Ibadan    8.5  NaN    NaN        NaN  4000.0       5.0  NaN  20000.0  4005.0
# ...

# %%
print(real_boss)
# Out:
#              S/N Date Branch Pizza Sold   Price  Quantity Time  Revenue  \
# Gbagada      5.0  NaN    NaN        NaN  2000.0       4.0  NaN   8000.0
# Ibadan       1.0  NaN    NaN        NaN  2000.0       5.0  NaN  10000.0
# Ikoyi        3.0  NaN    NaN        NaN  2000.0       2.5  NaN   5000.0
# Lekki        3.0  NaN    NaN        NaN  4000.0       5.0  NaN  20000.0
# Gbagada      9.0  NaN    NaN        NaN  2000.0       3.0  NaN   6000.0
# ...          ...  ...    ...        ...     ...       ...  ...      ...
# Lekki     4994.0  NaN    NaN        NaN  4000.0       4.0  NaN  16000.0
# Gbagada   4999.0  NaN    NaN        NaN  3000.0       1.0  NaN   3000.0
# Ikoyi     4999.0  NaN    NaN        NaN  3000.0       4.5  NaN  13500.0
# Lekki     4996.0  NaN    NaN        NaN  4000.0       1.0  NaN   4000.0
# Surulere  4997.0  NaN    NaN        NaN  3000.0       5.0  NaN  15000.0
#
#             Snap
# Gbagada   2004.0
# Ibadan    2005.0
# Ikoyi     2002.5
# Lekki     4005.0
# ...

# %%
new_boss.head(5)
# Out:
#         S/N Date Branch Pizza Sold Price Quantity Time Revenue  Snap
# Gbagada   5  NaN    NaN        NaN  2000        4  NaN    8000  2004
# Ibadan    1  NaN    NaN        NaN  2000        5  NaN   10000  2005
# Ikoyi     6  NaN    NaN        NaN  4000        5  NaN   10000  4005
# Lekki     3  NaN    NaN        NaN  4000        5  NaN   20000  4005
# Gbagada   9  NaN    NaN        NaN  2000        3  NaN    6000  2003

# %%
print(Bee)
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]
