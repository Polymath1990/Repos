# %%
from google.cloud import bigquery

# %%
bigquery_client = bigquery.Client()

# %%
QUERY = """
SELECT
*
FROM 
`kwikbi.analytics_190725145.events_20210308`
LIMIT 
  1000
"""

# %%
query_job = bigquery_client.query(QUERY)

# %%
df = query_job.to_dataframe()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\google\cloud\bigquery\client.py:444: UserWarning: Cannot create BigQuery Storage client, the dependency google-cloud-bigquery-storage is not installed.
#   warnings.warn(

# %%
df.head()
# Out:
#   event_date   event_timestamp     event_name  \
# 0   20210308  1615215373751827    first_visit
# 1   20210308  1615215373751827  session_start
# 2   20210308  1615215373751827      page_view
# 3   20210308  1615218255403455    first_visit
# 4   20210308  1615218255403455  session_start
#
#                                         event_params  \
# 0  [{'key': 'page_location', 'value': {'string_va...
# 1  [{'key': 'ga_session_number', 'value': {'strin...
# 2  [{'key': 'term', 'value': {'string_value': '(n...
# 3  [{'key': 'page_location', 'value': {'string_va...
# 4  [{'key': 'page_title', 'value': {'string_value...
#
#    event_previous_timestamp  event_value_in_usd  event_bundle_sequence_id  \
# 0                       NaN                 NaN               -1567189485
# 1                       NaN                 NaN               -1567189485
# 2                       NaN                 NaN               -1567189485
# 3                       NaN                 NaN                1314462143
# 4                       NaN                 NaN                1314462143
#
#    event_server_timestamp_offset user_id       user_pseudo_id  ...  \
# 0                            NaN    None   2235698.1615215354  ...
# 1                            NaN    None   2235698.1615215354  ...
# 2                            NaN    None   2235698.1615215354  ...
# 3                            NaN    None  15194892.1615218252  ...
# 4                            NaN    None  15194892.1615218252  ...
#
#                               user_ltv  \
# 0  {'revenue': 0.0, 'currency': 'USD'}
# 1  {'revenue': 0.0, 'currency': 'USD'}
# 2  {'revenue': 0.0, 'currency': 'USD'}
# 3  {'revenue': 0.0, 'currency': 'USD'}
# 4  {'revenue': 0.0, 'currency': 'USD'}
#
#                                               device  \
# 0  {'category': 'desktop', 'mobile_brand_name': '...
# 1  {'category': 'desktop', 'mobile_brand_name': '...
# 2  {'category': 'desktop', 'mobile_brand_name': '...
# 3  {'category': 'mobile', 'mobile_brand_name': 'S...
# 4  {'category': 'mobile', 'mobile_brand_name': 'S...
#
#                                                  geo app_info  \
# 0  {'continent': 'Africa', 'country': 'Nigeria', ...     None
# 1  {'continent': 'Africa', 'country': 'Nigeria', ...     None
# 2  {'continent': 'Africa', 'country': 'Nigeria', ...     None
# 3  {'continent': 'Africa', 'country': 'Nigeria', ...     None
# 4  {'continent': 'Africa', 'country': 'Nigeria', ...     None
#
#                                       traffic_source   stream_id platform  \
# 0  {'name': '(organic)', 'medium': 'organic', 'so...  2306692446      WEB
# 1  {'name': '(organic)', 'medium': 'organic', 'so...  2306692446      WEB
# 2  {'name': '(organic)', 'medium': 'organic', 'so...  2306692446      WEB
# 3  {'name': '(organic)', 'medium': 'organic', 'so...  2306692446      WEB
# 4  {'name': '(organic)', 'medium': 'organic', 'so...  2306692446      WEB
#
#   event_dimensions ecommerce items
# 0             None      None    []
# 1             None      None    []
# 2             None      None    []
# 3             None      None    []
# 4             None      None    []
#
# [5 rows x 22 columns]

# %%
df
# Out:
#     event_date   event_timestamp       event_name  \
# 0     20210308  1615215373751827      first_visit
# 1     20210308  1615215373751827    session_start
# 2     20210308  1615215373751827        page_view
# 3     20210308  1615218255403455      first_visit
# 4     20210308  1615218255403455    session_start
# ..         ...               ...              ...
# 995   20210308  1615208513745607      first_visit
# 996   20210308  1615208513745607    session_start
# 997   20210308  1615208513745607        page_view
# 998   20210308  1615208631006192  user_engagement
# 999   20210308  1615208634540314        page_view
#
#                                           event_params  \
# 0    [{'key': 'page_location', 'value': {'string_va...
# 1    [{'key': 'ga_session_number', 'value': {'strin...
# 2    [{'key': 'term', 'value': {'string_value': '(n...
# 3    [{'key': 'page_location', 'value': {'string_va...
# 4    [{'key': 'page_title', 'value': {'string_value...
# ..                                                 ...
# 995  [{'key': 'page_title', 'value': {'string_value...
# 996  [{'key': 'page_location', 'value': {'string_va...
# 997  [{'key': 'page_location', 'value': {'string_va...
# 998  [{'key': 'campaign', 'value': {'string_value':...
# 999  [{'key': 'ga_session_number', 'value': {'strin...
#
#      event_previous_timestamp  event_value_in_usd  event_bundle_sequence_id  \
# 0                         NaN                 NaN               -1567189485
# 1                         NaN                 NaN               -1567189485
# 2                         NaN                 NaN               -1567189485
# 3                         NaN                 NaN                1314462143
# 4                         NaN                 NaN                1314462143
# ..                        ...                 ...                       ...
# 995                       NaN                 NaN                 162738887
# 996                       NaN                 NaN                 162738887
# 997                       NaN                 NaN                 162738887
# 998                       NaN                 NaN                 279999472
# 999                       NaN                 NaN                 283533594
#
#      event_server_timestamp_offset user_id        user_pseudo_id  ...  \
# 0                              NaN    None    2235698.1615215354  ...
# 1                              NaN    None    2235698.1615215354  ...
# 2                              NaN    None    2235698.1615215354  ...
# 3                              NaN    None   15194892.1615218252  ...
# 4                              NaN    None   15194892.1615218252  ...
# ..                             ...     ...                   ...  ...
# 995                            NaN    None  856408669.1615208510  ...
# 996                            NaN    None  856408669.1615208510  ...
# 997                            NaN    None  856408669.1615208510  ...
# 998                            NaN    None  856408669.1615208510  ...
# 999                            NaN    None  856408669.1615208510  ...
#
#                                 user_ltv  \
# 0    {'revenue': 0.0, 'currency': 'USD'}
# 1    {'revenue': 0.0, 'currency': 'USD'}
# 2    {'revenue': 0.0, 'currency': 'USD'}
# 3    {'revenue': 0.0, 'currency': 'USD'}
# 4    {'revenue': 0.0, 'currency': 'USD'}
# ..                                   ...
# 995  {'revenue': 0.0, 'currency': 'USD'}
# 996  {'revenue': 0.0, 'currency': 'USD'}
# 997  {'revenue': 0.0, 'currency': 'USD'}
# 998  {'revenue': 0.0, 'currency': 'USD'}
# 999  {'revenue': 0.0, 'currency': 'USD'}
#
#                                                 device  \
# 0    {'category': 'desktop', 'mobile_brand_name': '...
# 1    {'category': 'desktop', 'mobile_brand_name': '...
# 2    {'category': 'desktop', 'mobile_brand_name': '...
# 3    {'category': 'mobile', 'mobile_brand_name': 'S...
# 4    {'category': 'mobile', 'mobile_brand_name': 'S...
# ..                                                 ...
# 995  {'category': 'desktop', 'mobile_brand_name': '...
# 996  {'category': 'desktop', 'mobile_brand_name': '...
# 997  {'category': 'desktop', 'mobile_brand_name': '...
# 998  {'category': 'desktop', 'mobile_brand_name': '...
# 999  {'category': 'desktop', 'mobile_brand_name': '...
#
#                                                    geo app_info  \
# 0    {'continent': 'Africa', 'country': 'Nigeria', ...     None
# 1    {'continent': 'Africa', 'country': 'Nigeria', ...     None
# 2    {'continent': 'Africa', 'country': 'Nigeria', ...     None
# 3    {'continent': 'Africa', 'country': 'Nigeria', ...     None
# 4    {'continent': 'Africa', 'country': 'Nigeria', ...     None
# ..                                                 ...      ...
# 995  {'continent': 'Africa', 'country': 'Nigeria', ...     None
# 996  {'continent': 'Africa', 'country': 'Nigeria', ...     None
# 997  {'continent': 'Africa', 'country': 'Nigeria', ...     None
# 998  {'continent': 'Africa', 'country': 'Nigeria', ...     None
# 999  {'continent': 'Africa', 'country': 'Nigeria', ...     None
#
#                                         traffic_source   stream_id platform  \
# 0    {'name': '(organic)', 'medium': 'organic', 'so...  2306692446      WEB
# 1    {'name': '(organic)', 'medium': 'organic', 'so...  2306692446      WEB
# 2    {'name': '(organic)', 'medium': 'organic', 'so...  2306692446      WEB
# 3    {'name': '(organic)', 'medium': 'organic', 'so...  2306692446      WEB
# 4    {'name': '(organic)', 'medium': 'organic', 'so...  2306692446      WEB
# ..                                                 ...         ...      ...
# 995  {'name': '(organic)', 'medium': 'organic', 'so...  2306692446      WEB
# 996  {'name': '(organic)', 'medium': 'organic', 'so...  2306692446      WEB
# 997  {'name': '(organic)', 'medium': 'organic', 'so...  2306692446      WEB
# 998  {'name': '(organic)', 'medium': 'organic', 'so...  2306692446      WEB
# 999  {'name': '(organic)', 'medium': 'organic', 'so...  2306692446      WEB
#
#     event_dimensions ecommerce items
# 0               None      None    []
# 1               None      None    []
# 2               None      None    []
# 3               None      None    []
# 4               None      None    []
# ..               ...       ...   ...
# 995             None      None    []
# 996             None      None    []
# 997             None      None    []
# 998             None      None    []
# 999             None      None    []
#
# [1000 rows x 22 columns]

# %%
# %load_ext google.cloud.bigquery
# Out:
# The google.cloud.bigquery extension is already loaded. To reload it, use:
#   %reload_ext google.cloud.bigquery

# %%
# %%bigquery tax_forms --use_bqstorage_api
# SELECT * FROM `kwikbi.analytics_190725145.events_20210308`
# Out:
# Query complete after 0.00s: 100%|████████████████████████████████████████████████████| 1/1 [00:00<00:00, 501.29query/s]
# Downloading: 100%|████████████████████████████████████████████████████████████| 71535/71535 [01:57<00:00, 609.83rows/s]

# %%
bayoray = %sql SELECT * FROM `kwikbi.analytics_190725145.events_20210308
# Out:
# UsageError: Line magic function `%sql` not found.

# %%
# %%bigquery stackoverflow --use_bqstorage_api
# SELECT
#   CONCAT(
#     'https://stackoverflow.com/questions/',
#     CAST(id as STRING)) as url,
#   view_count
# FROM `bigquery-public-data.stackoverflow.posts_questions`
# WHERE tags like '%google-bigquery%'
# ORDER BY view_count DESC
# LIMIT 10

# %%
# Download query results.
query_string = """
SELECT
CONCAT(
    'https://stackoverflow.com/questions/',
    CAST(id as STRING)) as url,
view_count
FROM `bigquery-public-data.stackoverflow.posts_questions`
WHERE tags like '%google-bigquery%'
ORDER BY view_count DESC
"""

dataframe = (
    bqclient.query(query_string)
    .result()
    .to_dataframe(bqstorage_client=bqstorageclient)
)
print(dataframe.head())

# %%
# Download a table.
table = bigquery.TableReference.from_string(
    "bigquery-public-data.utility_us.country_code_iso"
)
rows = bqclient.list_rows(
    table,
    selected_fields=[
        bigquery.SchemaField("country_name", "STRING"),
        bigquery.SchemaField("fips_code", "STRING"),
    ],
)
dataframe = rows.to_dataframe(bqstorage_client=bqstorageclient)
print(dataframe.head())

# %%
project_id = "bigquery-public-data"
dataset_id = "new_york_trees"
table_id = "tree_species"
table = f"projects/{project_id}/datasets/{dataset_id}/tables/{table_id}"

# Select columns to read with read options. If no read options are
# specified, the whole table is read.
read_options = types.ReadSession.TableReadOptions(
    selected_fields=["species_common_name", "fall_color"]
)

parent = "projects/{}".format(your_project_id)

requested_session = types.ReadSession(
    table=table,
    # This API can also deliver data serialized in Apache Avro format.
    # This example leverages Apache Arrow.
    data_format=types.DataFormat.ARROW,
    read_options=read_options,
)
read_session = bqstorageclient.create_read_session(
    parent=parent, read_session=requested_session, max_stream_count=1,
)

# This example reads from only a single stream. Read from multiple streams
# to fetch data faster. Note that the session may not contain any streams
# if there are no rows to read.
stream = read_session.streams[0]
reader = bqstorageclient.read_rows(stream.name)

# Parse all Arrow blocks and create a dataframe. This call requires a
# session, because the session contains the schema for the row blocks.
dataframe = reader.to_dataframe(read_session)
print(dataframe.head())
