# %%
import pandas as pd

# %%
import numpy as np

# %%
jobfifteen = pd.read_csv('jobfifteen.csv')

# %%
taskie = pd.read_csv('taskvieworders.csv')

# %%
taska = pd.DataFrame(taskie)

# %%
jobfourfd = pd.DataFrame(jobfifteen)

# %%
ordermonth = pd.DataFrame(ordervol)

# %%
taska
# Out:
#           created_datetime pickup_delivery_relationship
# 0      2019-06-14 13:14:47           115605180876629162
# 1      2019-06-14 13:17:15           315605182351534498
# 2      2019-06-14 13:22:16           515605185364777221
# 3      2019-06-17 05:40:50           715607500508593155
# 4      2019-06-17 06:28:04           915607528840504488
# ...                    ...                          ...
# 43745  2021-01-11 14:37:54      11245516103758748101938
# 43746  2021-01-11 14:39:01      11245716103759415284842
# 43747  2021-01-11 14:40:03      11245916103760031313704
# 43748  2021-01-11 14:40:55      11246116103760559744523
# 43749  2021-01-11 14:42:00      11246316103761202197202
#
# [43750 rows x 2 columns]

# %%
import datetime

# %%
taska["job_date"] = pd.to_datetime(taska["created_datetime"])

# %%
taska['job_month_year'] = pd.to_datetime(taska['job_date']).dt.to_period('M')

# %%
ordermonth['job_month_year'] = pd.to_datetime(ordermonth['job_date']).dt.to_period('M')

# %%
taska
# Out:
#           created_datetime pickup_delivery_relationship            job_date  \
# 0      2019-06-14 13:14:47           115605180876629162 2019-06-14 13:14:47
# 1      2019-06-14 13:17:15           315605182351534498 2019-06-14 13:17:15
# 2      2019-06-14 13:22:16           515605185364777221 2019-06-14 13:22:16
# 3      2019-06-17 05:40:50           715607500508593155 2019-06-17 05:40:50
# 4      2019-06-17 06:28:04           915607528840504488 2019-06-17 06:28:04
# ...                    ...                          ...                 ...
# 43745  2021-01-11 14:37:54      11245516103758748101938 2021-01-11 14:37:54
# 43746  2021-01-11 14:39:01      11245716103759415284842 2021-01-11 14:39:01
# 43747  2021-01-11 14:40:03      11245916103760031313704 2021-01-11 14:40:03
# 43748  2021-01-11 14:40:55      11246116103760559744523 2021-01-11 14:40:55
# 43749  2021-01-11 14:42:00      11246316103761202197202 2021-01-11 14:42:00
#
#       job_month_year
# 0            2019-06
# ...

# %%
ordermonth.to_csv('jodder.csv', index = False)

# %%
jobfourfd['job_month_year'] = pd.to_datetime(jobfourfd['job_date']).dt.to_period('M')

# %%
jobfourfd
# Out:
#         Status         Id        Reference Channel  \
# 0      success  183492816    1559126258026    card
# 1      success  183494537     trx_wwlexe35    card
# 2      success  183496122     trx_f45oifx7    card
# 3      success  183547349     trx_1xvlov89    card
# 4      success  183548463     trx_pj2c117k    card
# ...        ...        ...              ...     ...
# 25299  success  923915450  b85r208yq3ob7jz    card
# 25300  success  923915873  5maf25q6rice4n4    card
# 25301  success  923920003     trx_kk56spp1    card
# 25302  success  923927585     trx_5lxkyh3i    card
# 25303  success  923932855  0ghb3cw1s9cu1oh    card
#
#                        Created At Currency  Amount   Fees  Amount Due  \
# 0      May 29th, 2019 10:37:39 AM      NGN    50.0   0.75       49.25
# 1      May 29th, 2019 10:43:24 AM      NGN    50.0   0.75       49.25
# 2      May 29th, 2019 10:48:17 AM      NGN    50.0   0.75       49.25
# ...

# %%
jobfourfd["job_timey"] = pd.to_datetime(jobfourfd["job_time_utc"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'job_time_utc'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-f0d017bd7768> in <module>
# ...

# %%
jobfourfd["job_hour"] = jobfourfd["job_timey"].dt.hour
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'job_timey'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-6f137aef3266> in <module>
# ...

# %%
jobfourfd
# Out:
#         Status         Id        Reference Channel  \
# 0      success  183492816    1559126258026    card
# 1      success  183494537     trx_wwlexe35    card
# 2      success  183496122     trx_f45oifx7    card
# 3      success  183547349     trx_1xvlov89    card
# 4      success  183548463     trx_pj2c117k    card
# ...        ...        ...              ...     ...
# 25299  success  923915450  b85r208yq3ob7jz    card
# 25300  success  923915873  5maf25q6rice4n4    card
# 25301  success  923920003     trx_kk56spp1    card
# 25302  success  923927585     trx_5lxkyh3i    card
# 25303  success  923932855  0ghb3cw1s9cu1oh    card
#
#                        Created At Currency  Amount   Fees  Amount Due  \
# 0      May 29th, 2019 10:37:39 AM      NGN    50.0   0.75       49.25
# 1      May 29th, 2019 10:43:24 AM      NGN    50.0   0.75       49.25
# 2      May 29th, 2019 10:48:17 AM      NGN    50.0   0.75       49.25
# ...

# %%
oders = ordermonth.groupby('job_month_year').sum()

# %%
oders.reset_index()
# Out:
#    job_month_year  orda      amount
# 0         2019-01    35        0.00
# 1         2019-02    64        0.00
# 2         2019-03    74        0.00
# 3         2019-04    99        0.00
# 4         2019-05    81        0.00
# 5         2019-06   136        0.00
# 6         2019-07   179        0.00
# 7         2019-08   228        0.00
# 8         2019-09   218        0.00
# 9         2019-10   339        0.00
# 10        2019-11   406        0.00
# 11        2019-12   479        0.00
# 12        2020-01  1440  1035566.55
# 13        2020-02  1936  1243342.87
# 14        2020-03  2239  1266705.89
# 15        2020-04  4350  1166880.18
# 16        2020-05  3064  1193788.13
# 17        2020-06  3296   976465.53
# 18        2020-07  4095  2391487.92
# 19        2020-08  3722  4963953.11
# 20        2020-09  4261  5681607.95
# 21        2020-10  3515  4612415.91
# 22        2020-11  4165  6147169.54
# 23        2020-12  4299  7338530.59
# 24        2021-01    36    87691.90
# ...

# %%
jobfourfd['count']=1
jobfourfd.groupby(['job_month_date', 'orda']).count()['count']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-46-ec85de5bfdc7> in <module>
#       1 jobfourfd['count']=1
# ----> 2 jobfourfd.groupby(['Card Type', 'job_date']).count()['count']
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed)
#    5799         axis = self._get_axis_number(axis)
#    5800
# -> 5801         return groupby_generic.DataFrameGroupBy(
#    5802             obj=self,
#    5803             keys=by,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated)
#     401             from pandas.core.groupby.grouper import get_grouper
#     402
# --> 403             grouper, exclusions, obj = get_grouper(
# ...

# %%
jobamount
# Out:
#                             Id  Amount   Fees  Amount Due
# job_date
# 2019-05-29 10:37:39  183492816    50.0   0.75       49.25
# 2019-05-29 10:43:24  183494537    50.0   0.75       49.25
# 2019-05-29 10:48:17  183496122    50.0   0.75       49.25
# 2019-05-29 12:41:41  183547349    50.0   0.75       49.25
# 2019-05-29 12:45:16  183548463    50.0   0.75       49.25
# ...                        ...     ...    ...         ...
# 2020-12-15 14:23:41  923915450  1400.0  21.00     1379.00
# 2020-12-15 14:24:06  923915873  1800.0  27.00     1773.00
# 2020-12-15 14:28:08  923920003    50.0   0.75       49.25
# 2020-12-15 14:34:29  923927585    50.0   0.75       49.25
# 2020-12-15 14:38:35  923932855  2400.0  36.00     2364.00
#
# [25271 rows x 4 columns]

# %%
trial = pd.DataFrame({'sum' : jobfourfd.groupby( [ 'job_month_year', 'Amount'] ).size()}).reset_index()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-41-d666d8e9f7d4> in <module>
# ----> 1 trial = pd.DataFrame({'sum' : jobfourfd.groupby( [ 'job_month_year', 'Amount'] ).size()}).reset_index()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed)
#    5799         axis = self._get_axis_number(axis)
#    5800
# -> 5801         return groupby_generic.DataFrameGroupBy(
#    5802             obj=self,
#    5803             keys=by,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated)
#     401             from pandas.core.groupby.grouper import get_grouper
#     402
# ...

# %%
jobdeck = jobdecfd[jobdecfd['customer_id'] == 29417]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-09a922594800> in <module>
# ----> 1 jobdeck = jobdecfd[jobdecfd['customer_id'] == 29417]
#
# NameError: name 'jobdecfd' is not defined

# %%
import time

# %%
jobdeck['job_delivery_datetime']
# Out:
# 86726    0000-00-00 00:00:00
# 87284    0000-00-00 00:00:00
# 87791    0000-00-00 00:00:00
# 88985    0000-00-00 00:00:00
# 89041    0000-00-00 00:00:00
# 89415    0000-00-00 00:00:00
# 89429    0000-00-00 00:00:00
# 89864    0000-00-00 00:00:00
# 90437    0000-00-00 00:00:00
# 90752    0000-00-00 00:00:00
# 91480    0000-00-00 00:00:00
# 91996    0000-00-00 00:00:00
# 92015    0000-00-00 00:00:00
# 92070    0000-00-00 00:00:00
# 95964    0000-00-00 00:00:00
# 96088    0000-00-00 00:00:00
# Name: job_delivery_datetime, dtype: object

# %%
jobdeck
# Out:
#        job_id  created_by order_id recurring_id  recurring_count  \
# 86726   86778           3    23862            0                0
# 87284   87336           3    23862            0                0
# 87791   87843           3    23862            0                0
# 88985   89037           3    23862            0                0
# 89041   89093           3    23862            0                0
# 89415   89467           3    23862            0                0
# 89429   89481           3    23862            0                0
# 89864   89916           3    23862            0                0
# 90437   90489           3    23862            0                0
# 90752   90804           3    23862            0                0
# 91480   91532           3    23862            0                0
# 91996   92048           3    23862            0                0
# 92015   92067           3    23862            0                0
# ...

# %%
import datetime

# %%
jobdeck["job_datey"] = pd.to_datetime(jobdeck["job_date"])
# Out:
# <ipython-input-113-9bbcb2d4d057>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jobdeck["job_datey"] = pd.to_datetime(jobdeck["job_date"])

# %%
jobdeck['job_month_year'] = pd.to_datetime(jobdeck['job_date']).dt.to_period('M')
# Out:
# <ipython-input-115-bf72f507de98>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jobdeck['job_month_year'] = pd.to_datetime(jobdeck['job_date']).dt.to_period('M')

# %%
jobdeck['job_month_year']
# Out:
#        job_id  created_by order_id recurring_id  recurring_count  \
# 86726   86778           3    23862            0                0
# 87284   87336           3    23862            0                0
# 87791   87843           3    23862            0                0
# 88985   89037           3    23862            0                0
# 89041   89093           3    23862            0                0
# 89415   89467           3    23862            0                0
# 89429   89481           3    23862            0                0
# 89864   89916           3    23862            0                0
# 90437   90489           3    23862            0                0
# 90752   90804           3    23862            0                0
# 91480   91532           3    23862            0                0
# 91996   92048           3    23862            0                0
# 92015   92067           3    23862            0                0
# ...

# %%
import time

# %%
jobdeck["creation_datetime"] = pd.to_datetime(jobdeck["creation_datetime"])
# Out:
# <ipython-input-119-49653d4941e7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jobdeck["creation_datetime"] = pd.to_datetime(jobdeck["creation_datetime"])

# %%
jobdeck['job_delivery_datetime'] = jobdeck['job_delivery_datetime'].replace(['0000-00-00 00:00:00'],'')
# Out:
# <ipython-input-120-2d3ad30155bd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jobdeck['job_delivery_datetime'] = jobdeck['job_delivery_datetime'].replace(['0000-00-00 00:00:00'],'')

# %%
jobdeck['job_pickup_datetime'] = jobdeck['job_pickup_datetime'].replace(['0000-00-00 00:00:00'],'')
# Out:
# <ipython-input-121-4162d7356f53>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jobdeck['job_pickup_datetime'] = jobdeck['job_pickup_datetime'].replace(['0000-00-00 00:00:00'],'')

# %%
jobdeck["recreate_deliver"] = pd.to_datetime(jobdeck["job_delivery_datetime"])
# Out:
# <ipython-input-122-d073af0df81d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jobdeck["recreate_deliver"] = pd.to_datetime(jobdeck["job_delivery_datetime"])

# %%
jobdeck["recreate_pick"] = pd.to_datetime(jobdeck["job_pickup_datetime"])
# Out:
# <ipython-input-123-250fe6de6e28>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jobdeck["recreate_pick"] = pd.to_datetime(jobdeck["job_pickup_datetime"])

# %%
jobdeck['create_month'] = pd.to_datetime(jobdeck['creation_datetime']).dt.to_period('M')
# Out:
# <ipython-input-124-ee46f9d226d9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jobdeck['create_month'] = pd.to_datetime(jobdeck['creation_datetime']).dt.to_period('M')

# %%
jobdeck['pick_month'] = pd.to_datetime(jobdeck['job_pickup_datetime']).dt.to_period('M')
# Out:
# <ipython-input-125-a461461d5b23>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jobdeck['pick_month'] = pd.to_datetime(jobdeck['job_pickup_datetime']).dt.to_period('M')

# %%
jobdeck['deliver_month'] = pd.to_datetime(jobdeck['job_delivery_datetime']).dt.to_period('M')
# Out:
# <ipython-input-126-00a312333f4a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jobdeck['deliver_month'] = pd.to_datetime(jobdeck['job_delivery_datetime']).dt.to_period('M')

# %%
jobdeck["job_delivery_datetime"]
# Out:
# 86726
# 87284
# 87791
# 88985
# 89041
# 89415
# 89429
# 89864
# 90437
# 90752
# 91480
# 91996
# 92015
# 92070
# 95964
# 96088
# Name: job_delivery_datetime, dtype: object

# %%
jobdeck["created_hour"] = jobdeck["creation_datetime"].dt.hour
# Out:
# <ipython-input-131-58f499dce486>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jobdeck["created_hour"] = jobdeck["creation_datetime"].dt.hour

# %%
jobdeck["pick_hour"] = jobdeck["recreate_pick"].dt.hour
# Out:
# <ipython-input-132-1580882f5ae2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jobdeck["pick_hour"] = jobdeck["recreate_pick"].dt.hour

# %%
jobdeck["deliver_hour"] = jobdeck["recreate_deliver"].dt.hour
# Out:
# <ipython-input-133-ad4d8b0429c6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jobdeck["deliver_hour"] = jobdeck["recreate_deliver"].dt.hour

# %%
jobdeck["deliver_min"] =jobdeck["recreate_deliver"].dt.minute
# Out:
# <ipython-input-134-adde4f19b395>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jobdeck["deliver_min"] =jobdeck["recreate_deliver"].dt.minute

# %%
jobdeck["deliver_sec"] = jobdeck["recreate_deliver"].dt.second
# Out:
# <ipython-input-135-9dafe76ea01d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jobdeck["deliver_sec"] = jobdeck["recreate_deliver"].dt.second

# %%
jobdeck["pick_hour"] = jobdeck["recreate_pick"].dt.hour
# Out:
# <ipython-input-136-1580882f5ae2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jobdeck["pick_hour"] = jobdeck["recreate_pick"].dt.hour

# %%
jobdeck["pick_min"] = jobdeck["recreate_pick"].dt.minute
# Out:
# <ipython-input-137-44128e9dbfda>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jobdeck["pick_min"] = jobdeck["recreate_pick"].dt.minute

# %%
jobdeck["pick_sec"] = jobdeck["recreate_pick"].dt.second
# Out:
# <ipython-input-138-2e2e1b632862>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jobdeck["pick_sec"] = jobdeck["recreate_pick"].dt.second

# %%
jobdeck["created_min"] = jobdeck["creation_datetime"].dt.minute
# Out:
# <ipython-input-140-0c0b2af66609>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jobdeck["created_min"] = jobdeck["creation_datetime"].dt.minute

# %%
jobdeck["created_sec"] = jobdeck["creation_datetime"].dt.second
# Out:
# <ipython-input-141-5a3aae9eb082>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jobdeck["created_sec"] = jobdeck["creation_datetime"].dt.second

# %%
jobdeck['pick_hour_diff'] = jobdeck['pick_hour'] - jobdeck['created_hour']
# Out:
# <ipython-input-142-a82740d73f23>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jobdeck['pick_hour_diff'] = jobdeck['pick_hour'] - jobdeck['created_hour']

# %%
jobdeck['pick_min_diff'] = jobdeck['pick_min'] - jobdeck['created_min']
# Out:
# <ipython-input-143-ecf2c506ed6e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jobdeck['pick_min_diff'] = jobdeck['pick_min'] - jobdeck['created_min']

# %%
jobdeck['pick_sec_diff'] = jobdeck['pick_sec'] - jobdeck['created_sec']
# Out:
# <ipython-input-145-6e958c57dcb0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jobdeck['pick_sec_diff'] = jobdeck['pick_sec'] - jobdeck['created_sec']

# %%
jobdeck['deliver_hour_diff'] = jobdeck['deliver_hour'] - jobdeck['created_hour']
# Out:
# <ipython-input-144-4c057d6fef37>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jobdeck['deliver_hour_diff'] = jobdeck['deliver_hour'] - jobdeck['created_hour']

# %%
jobdeck['deliver_min_diff'] = jobdeck['deliver_min'] - jobdeck['created_min']
# Out:
# <ipython-input-146-bfab567129aa>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jobdeck['deliver_min_diff'] = jobdeck['deliver_min'] - jobdeck['created_min']

# %%
jobdeck['deliver_sec_diff'] = jobdeck['deliver_sec'] - jobdeck['created_sec']
# Out:
# <ipython-input-147-b6fd57cb96d4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jobdeck['deliver_sec_diff'] = jobdeck['deliver_sec'] - jobdeck['created_sec']

# %%
jobdeck['final_deliver_hour_min'] = jobdeck['deliver_hour_diff'] * 60
# Out:
# <ipython-input-148-a349da8d00ec>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jobdeck['final_deliver_hour_min'] = jobdeck['deliver_hour_diff'] * 60

# %%
jobdeck['final_pick_hour_min'] = jobdeck['pick_hour_diff'] * 60
# Out:
# <ipython-input-149-c2f9ea72cdfe>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jobdeck['final_pick_hour_min'] = jobdeck['pick_hour_diff'] * 60

# %%
jobdeck['total_pick_min_diff'] = jobdeck['final_pick_hour_min'] + jobdeck['pick_min_diff']
# Out:
# <ipython-input-150-b0f8a83ce7aa>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jobdeck['total_pick_min_diff'] = jobdeck['final_pick_hour_min'] + jobdeck['pick_min_diff']

# %%
jobdeck['total_deliver_min_diff'] = jobdeck['final_deliver_hour_min'] + jobdeck['deliver_min_diff']
# Out:
# <ipython-input-151-a9ab8e8abd80>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jobdeck['total_deliver_min_diff'] = jobdeck['final_deliver_hour_min'] + jobdeck['deliver_min_diff']

# %%
jobdeck
# Out:
#        job_id  created_by order_id recurring_id  recurring_count  \
# 86726   86778           3    23862            0                0
# 87284   87336           3    23862            0                0
# 87791   87843           3    23862            0                0
# 88985   89037           3    23862            0                0
# 89041   89093           3    23862            0                0
# 89415   89467           3    23862            0                0
# 89429   89481           3    23862            0                0
# 89864   89916           3    23862            0                0
# 90437   90489           3    23862            0                0
# 90752   90804           3    23862            0                0
# 91480   91532           3    23862            0                0
# 91996   92048           3    23862            0                0
# 92015   92067           3    23862            0                0
# ...

# %%
takie = taska.groupby('job_month_year').count().reset_index()

# %%
takie
# Out:
#    job_month_year  created_datetime  pickup_delivery_relationship  job_date
# 0         2019-06                42                            42        42
# 1         2019-07               157                           157       157
# 2         2019-08               238                           238       238
# 3         2019-09               207                           207       207
# 4         2019-10               445                           445       445
# 5         2019-11               513                           513       513
# 6         2019-12               714                           714       714
# 7         2020-01               570                           570       570
# 8         2020-02               922                           922       922
# 9         2020-03              1292                          1292      1292
# 10        2020-04              4638                          4638      4638
# ...

# %%
jobber
# Out:
#             job_id  created_by  recurring_count  partner_order_id  team_id  \
# job_datey
# 2020-11-11   86778           3                0               0.0        1
# 2020-11-12   87336           3                0               0.0        1
# 2020-11-13   87843           3                0               0.0        1
# 2020-11-16  178130           6                0               0.0        2
# 2020-11-18  268864           9                0               0.0        3
# 2020-11-19   90489           3                0               0.0        1
# 2020-11-20   90804           3                0               0.0        1
# 2020-11-23   91532           3                0               0.0        1
# 2020-11-24  184170           6                0               0.0        2
# 2020-11-25   92067           3                0               0.0        1
# 2020-12-03  192156           6                0               0.0        2
#
# ...

# %%
takie.to_csv('tata.csv', index = False)
